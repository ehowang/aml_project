# %% [markdown]
# # Active Learning RandomSampling_Uncertainty_Sampling_XGBoost

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score
import matplotlib.pyplot as plt

# Load data
labeled_df = pd.read_csv("elliptic_txs_features_labeled.csv")

# Split train/test by time_step
train_df = labeled_df[labeled_df['time_step'] <= 34].reset_index(drop=True)
test_df = labeled_df[labeled_df['time_step'] >= 35].reset_index(drop=True)

X_test = test_df.drop(columns=['txId', 'time_step', 'class'])
y_test = (test_df['class'] == 1).astype(int)

feature_columns = [col for col in train_df.columns if col.startswith('feature_') or col.startswith('f')]

# Config
batch_size = 50
max_iterations = 60
N_runs = 5
all_f1_scores = []
warmup_sizes = []
active_sizes = []

for run in range(N_runs):
    print(f"\n=== Run {run+1}/{N_runs} ===")
    unlabeled_pool = train_df.copy().reset_index(drop=True)

    # --- Warm-up via Random Sampling ---
    labeled_pool = unlabeled_pool.sample(n=batch_size, random_state=run).copy()
    unlabeled_pool = unlabeled_pool.drop(labeled_pool.index).reset_index(drop=True)
    warmup_size = len(labeled_pool)
    warmup_sizes.append(warmup_size)

    f1_scores = []

    # --- Active Learning Loop (Uncertainty Sampling) ---
    for iteration in range(1, max_iterations + 1):
        X_train = labeled_pool[feature_columns]
        y_train = (labeled_pool['class'] == 1).astype(int)

        model = RandomForestClassifier(
            n_estimators=100,
            max_depth=10,
            random_state=run,
            n_jobs=-1
        )
        model.fit(X_train, y_train)

        y_pred = model.predict(X_test)
        f1 = f1_score(y_test, y_pred, pos_label=1)
        f1_scores.append(f1)
        print(f"[Run {run+1}] Iter {iteration} F1-illicit: {f1:.4f}")

        # --- Uncertainty sampling ---
        proba = model.predict_proba(unlabeled_pool[feature_columns])[:, 1]
        uncertainty = np.abs(proba - 0.5)
        select_idx = np.argsort(uncertainty)[:batch_size]

        new_batch = unlabeled_pool.iloc[select_idx]
        labeled_pool = pd.concat([labeled_pool, new_batch], ignore_index=True)
        unlabeled_pool = unlabeled_pool.drop(unlabeled_pool.index[select_idx]).reset_index(drop=True)

        if len(unlabeled_pool) == 0:
            break

    all_f1_scores.append(f1_scores)
    active_sizes.append(len(f1_scores) * batch_size)

# --- Evaluation ---
max_len = max(len(scores) for scores in all_f1_scores)
f1_matrix = np.full((N_runs, max_len), np.nan)
for i, scores in enumerate(all_f1_scores):
    f1_matrix[i, :len(scores)] = scores

median_f1_per_iter = np.nanmedian(f1_matrix, axis=0)
final_median_f1 = np.nanmedian([scores[-1] for scores in all_f1_scores if len(scores) == max_len])

# --- Output ---
print("\n=== Summary ===")
print("Median F1 per Iteration:")
for i, f1 in enumerate(median_f1_per_iter):
    print(f"Iteration {i+1:02d} ({(i+1)*batch_size} samples): Median F1 = {f1:.4f}")

print(f"\nFinal Median F1 (illicit): {round(final_median_f1, 4)}")
print("Average Warm-up size:", int(np.mean(warmup_sizes)))
print("Average Active Learning size:", int(np.mean(active_sizes)))
print("Average Final Training set size:", int(np.mean(np.array(warmup_sizes) + np.array(active_sizes))))

# --- Plot ---
plt.figure(figsize=(8, 5))
plt.plot(np.arange(1, len(median_f1_per_iter)+1)*batch_size, median_f1_per_iter, label='Median F1', marker='o')
plt.xlabel("Number of Labeled Samples")
plt.ylabel("Illicit F1-score")
plt.title("Active Learning: Random Init + Uncertainty Sampling + Random Forest")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# === Run 1/5 ===
# [Run 1] Iter 1 F1-illicit: 0.7607
# [Run 1] Iter 2 F1-illicit: 0.5568
# [Run 1] Iter 3 F1-illicit: 0.7389
# [Run 1] Iter 4 F1-illicit: 0.8073
# [Run 1] Iter 5 F1-illicit: 0.7392
# [Run 1] Iter 6 F1-illicit: 0.7757
# [Run 1] Iter 7 F1-illicit: 0.7898
# [Run 1] Iter 8 F1-illicit: 0.8032
# [Run 1] Iter 9 F1-illicit: 0.7887
# [Run 1] Iter 10 F1-illicit: 0.7573
# [Run 1] Iter 11 F1-illicit: 0.7909
# [Run 1] Iter 12 F1-illicit: 0.7406
# [Run 1] Iter 13 F1-illicit: 0.8050
# [Run 1] Iter 14 F1-illicit: 0.7854
# [Run 1] Iter 15 F1-illicit: 0.7917
# [Run 1] Iter 16 F1-illicit: 0.8047
# [Run 1] Iter 17 F1-illicit: 0.7964
# [Run 1] Iter 18 F1-illicit: 0.7898
# [Run 1] Iter 19 F1-illicit: 0.8152
# [Run 1] Iter 20 F1-illicit: 0.8099
# [Run 1] Iter 21 F1-illicit: 0.8111
# [Run 1] Iter 22 F1-illicit: 0.8049
# [Run 1] Iter 23 F1-illicit: 0.8083
# [Run 1] Iter 24 F1-illicit: 0.8031
# [Run 1] Iter 25 F1-illicit: 0.8154
# [Run 1] Iter 26 F1-illicit: 0.8135
# [Run 1] Iter 27 F1-illicit: 0.8128
# [Run 1] Iter 28 F1-illicit: 0.8058
# [Run 1] Iter 29 F1-illicit: 0.8205
# [Run 1] Iter 30 F1-illicit: 0.8235
# [Run 1] Iter 31 F1-illicit: 0.8166
# [Run 1] Iter 32 F1-illicit: 0.8268
# [Run 1] Iter 33 F1-illicit: 0.8239
# [Run 1] Iter 34 F1-illicit: 0.8215
# [Run 1] Iter 35 F1-illicit: 0.8208
# [Run 1] Iter 36 F1-illicit: 0.8214
# [Run 1] Iter 37 F1-illicit: 0.8225
# [Run 1] Iter 38 F1-illicit: 0.8235
# [Run 1] Iter 39 F1-illicit: 0.8188
# [Run 1] Iter 40 F1-illicit: 0.8223
# [Run 1] Iter 41 F1-illicit: 0.8212
# [Run 1] Iter 42 F1-illicit: 0.8261
# [Run 1] Iter 43 F1-illicit: 0.8184
# [Run 1] Iter 44 F1-illicit: 0.8258
# [Run 1] Iter 45 F1-illicit: 0.8199
# [Run 1] Iter 46 F1-illicit: 0.8173
# [Run 1] Iter 47 F1-illicit: 0.8286
# [Run 1] Iter 48 F1-illicit: 0.8290
# [Run 1] Iter 49 F1-illicit: 0.8238
# [Run 1] Iter 50 F1-illicit: 0.8193
# [Run 1] Iter 51 F1-illicit: 0.8236
# [Run 1] Iter 52 F1-illicit: 0.8197
# [Run 1] Iter 53 F1-illicit: 0.8199
# [Run 1] Iter 54 F1-illicit: 0.8244
# [Run 1] Iter 55 F1-illicit: 0.8215
# [Run 1] Iter 56 F1-illicit: 0.8225
# [Run 1] Iter 57 F1-illicit: 0.8219
# [Run 1] Iter 58 F1-illicit: 0.8206
# [Run 1] Iter 59 F1-illicit: 0.8246
# [Run 1] Iter 60 F1-illicit: 0.8225
#
# === Run 2/5 ===
# [Run 2] Iter 1 F1-illicit: 0.6127
# [Run 2] Iter 2 F1-illicit: 0.6356
# [Run 2] Iter 3 F1-illicit: 0.7360
# [Run 2] Iter 4 F1-illicit: 0.5425
# [Run 2] Iter 5 F1-illicit: 0.7457
# [Run 2] Iter 6 F1-illicit: 0.7619
# [Run 2] Iter 7 F1-illicit: 0.7526
# [Run 2] Iter 8 F1-illicit: 0.8029
# [Run 2] Iter 9 F1-illicit: 0.7798
# [Run 2] Iter 10 F1-illicit: 0.7706
# [Run 2] Iter 11 F1-illicit: 0.7298
# [Run 2] Iter 12 F1-illicit: 0.7058
# [Run 2] Iter 13 F1-illicit: 0.7838
# [Run 2] Iter 14 F1-illicit: 0.7788
# [Run 2] Iter 15 F1-illicit: 0.7806
# [Run 2] Iter 16 F1-illicit: 0.8044
# [Run 2] Iter 17 F1-illicit: 0.8157
# [Run 2] Iter 18 F1-illicit: 0.7974
# [Run 2] Iter 19 F1-illicit: 0.8069
# [Run 2] Iter 20 F1-illicit: 0.8078
# [Run 2] Iter 21 F1-illicit: 0.8110
# [Run 2] Iter 22 F1-illicit: 0.8174
# [Run 2] Iter 23 F1-illicit: 0.8245
# [Run 2] Iter 24 F1-illicit: 0.8045
# [Run 2] Iter 25 F1-illicit: 0.8208
# [Run 2] Iter 26 F1-illicit: 0.8107
# [Run 2] Iter 27 F1-illicit: 0.8238
# [Run 2] Iter 28 F1-illicit: 0.8179
# [Run 2] Iter 29 F1-illicit: 0.8102
# [Run 2] Iter 30 F1-illicit: 0.8222
# [Run 2] Iter 31 F1-illicit: 0.8219
# [Run 2] Iter 32 F1-illicit: 0.8157
# [Run 2] Iter 33 F1-illicit: 0.8178
# [Run 2] Iter 34 F1-illicit: 0.8195
# [Run 2] Iter 35 F1-illicit: 0.8277
# [Run 2] Iter 36 F1-illicit: 0.8232
# [Run 2] Iter 37 F1-illicit: 0.8130
# [Run 2] Iter 38 F1-illicit: 0.8215
# [Run 2] Iter 39 F1-illicit: 0.8227
# [Run 2] Iter 40 F1-illicit: 0.8198
# [Run 2] Iter 41 F1-illicit: 0.8274
# [Run 2] Iter 42 F1-illicit: 0.8259
# [Run 2] Iter 43 F1-illicit: 0.8212
# [Run 2] Iter 44 F1-illicit: 0.8219
# [Run 2] Iter 45 F1-illicit: 0.8245
# [Run 2] Iter 46 F1-illicit: 0.8217
# [Run 2] Iter 47 F1-illicit: 0.8182
# [Run 2] Iter 48 F1-illicit: 0.8215
# [Run 2] Iter 49 F1-illicit: 0.8217
# [Run 2] Iter 50 F1-illicit: 0.8161
# [Run 2] Iter 51 F1-illicit: 0.8200
# [Run 2] Iter 52 F1-illicit: 0.8220
# [Run 2] Iter 53 F1-illicit: 0.8168
# [Run 2] Iter 54 F1-illicit: 0.8195
# [Run 2] Iter 55 F1-illicit: 0.8238
# [Run 2] Iter 56 F1-illicit: 0.8202
# [Run 2] Iter 57 F1-illicit: 0.8167
# [Run 2] Iter 58 F1-illicit: 0.8187
# [Run 2] Iter 59 F1-illicit: 0.8172
# [Run 2] Iter 60 F1-illicit: 0.8118
#
# === Run 3/5 ===
# [Run 3] Iter 1 F1-illicit: 0.7164
# [Run 3] Iter 2 F1-illicit: 0.7657
# [Run 3] Iter 3 F1-illicit: 0.7576
# [Run 3] Iter 4 F1-illicit: 0.7142
# [Run 3] Iter 5 F1-illicit: 0.7678
# [Run 3] Iter 6 F1-illicit: 0.7512
# [Run 3] Iter 7 F1-illicit: 0.7255
# [Run 3] Iter 8 F1-illicit: 0.8083
# [Run 3] Iter 9 F1-illicit: 0.8051
# [Run 3] Iter 10 F1-illicit: 0.7922
# [Run 3] Iter 11 F1-illicit: 0.7536
# [Run 3] Iter 12 F1-illicit: 0.7840
# [Run 3] Iter 13 F1-illicit: 0.7699
# [Run 3] Iter 14 F1-illicit: 0.7834
# [Run 3] Iter 15 F1-illicit: 0.7904
# [Run 3] Iter 16 F1-illicit: 0.7724
# [Run 3] Iter 17 F1-illicit: 0.7648
# [Run 3] Iter 18 F1-illicit: 0.7744
# [Run 3] Iter 19 F1-illicit: 0.7654
# [Run 3] Iter 20 F1-illicit: 0.8134
# [Run 3] Iter 21 F1-illicit: 0.7764
# [Run 3] Iter 22 F1-illicit: 0.8112
# [Run 3] Iter 23 F1-illicit: 0.8002
# [Run 3] Iter 24 F1-illicit: 0.8235
# [Run 3] Iter 25 F1-illicit: 0.8188
# [Run 3] Iter 26 F1-illicit: 0.8161
# [Run 3] Iter 27 F1-illicit: 0.8245
# [Run 3] Iter 28 F1-illicit: 0.8198
# [Run 3] Iter 29 F1-illicit: 0.8274
# [Run 3] Iter 30 F1-illicit: 0.8220
# [Run 3] Iter 31 F1-illicit: 0.8273
# [Run 3] Iter 32 F1-illicit: 0.8235
# [Run 3] Iter 33 F1-illicit: 0.8313
# [Run 3] Iter 34 F1-illicit: 0.8282
# [Run 3] Iter 35 F1-illicit: 0.8256
# [Run 3] Iter 36 F1-illicit: 0.8184
# [Run 3] Iter 37 F1-illicit: 0.8201
# [Run 3] Iter 38 F1-illicit: 0.8246
# [Run 3] Iter 39 F1-illicit: 0.8237
# [Run 3] Iter 40 F1-illicit: 0.8210
# [Run 3] Iter 41 F1-illicit: 0.8216
# [Run 3] Iter 42 F1-illicit: 0.8166
# [Run 3] Iter 43 F1-illicit: 0.8140
# [Run 3] Iter 44 F1-illicit: 0.8248
# [Run 3] Iter 45 F1-illicit: 0.8260
# [Run 3] Iter 46 F1-illicit: 0.8247
# [Run 3] Iter 47 F1-illicit: 0.8301
# [Run 3] Iter 48 F1-illicit: 0.8252
# [Run 3] Iter 49 F1-illicit: 0.8225
# [Run 3] Iter 50 F1-illicit: 0.8244
# [Run 3] Iter 51 F1-illicit: 0.8203
# [Run 3] Iter 52 F1-illicit: 0.8246
# [Run 3] Iter 53 F1-illicit: 0.8233
# [Run 3] Iter 54 F1-illicit: 0.8178
# [Run 3] Iter 55 F1-illicit: 0.8260
# [Run 3] Iter 56 F1-illicit: 0.8256
# [Run 3] Iter 57 F1-illicit: 0.8236
# [Run 3] Iter 58 F1-illicit: 0.8226
# [Run 3] Iter 59 F1-illicit: 0.8248
# [Run 3] Iter 60 F1-illicit: 0.8261
#
# === Run 4/5 ===
# [Run 4] Iter 1 F1-illicit: 0.6445
# [Run 4] Iter 2 F1-illicit: 0.7105
# [Run 4] Iter 3 F1-illicit: 0.7326
# [Run 4] Iter 4 F1-illicit: 0.7741
# [Run 4] Iter 5 F1-illicit: 0.7750
# [Run 4] Iter 6 F1-illicit: 0.8075
# [Run 4] Iter 7 F1-illicit: 0.7934
# [Run 4] Iter 8 F1-illicit: 0.7482
# [Run 4] Iter 9 F1-illicit: 0.7397
# [Run 4] Iter 10 F1-illicit: 0.7496
# [Run 4] Iter 11 F1-illicit: 0.7538
# [Run 4] Iter 12 F1-illicit: 0.7315
# [Run 4] Iter 13 F1-illicit: 0.7735
# [Run 4] Iter 14 F1-illicit: 0.8138
# [Run 4] Iter 15 F1-illicit: 0.8014
# [Run 4] Iter 16 F1-illicit: 0.7869
# [Run 4] Iter 17 F1-illicit: 0.7797
# [Run 4] Iter 18 F1-illicit: 0.7926
# [Run 4] Iter 19 F1-illicit: 0.7912
# [Run 4] Iter 20 F1-illicit: 0.8091
# [Run 4] Iter 21 F1-illicit: 0.7881
# [Run 4] Iter 22 F1-illicit: 0.8067
# [Run 4] Iter 23 F1-illicit: 0.8068
# [Run 4] Iter 24 F1-illicit: 0.8177
# [Run 4] Iter 25 F1-illicit: 0.8152
# [Run 4] Iter 26 F1-illicit: 0.7959
# [Run 4] Iter 27 F1-illicit: 0.8014
# [Run 4] Iter 28 F1-illicit: 0.8124
# [Run 4] Iter 29 F1-illicit: 0.8232
# [Run 4] Iter 30 F1-illicit: 0.8187
# [Run 4] Iter 31 F1-illicit: 0.8219
# [Run 4] Iter 32 F1-illicit: 0.8225
# [Run 4] Iter 33 F1-illicit: 0.8235
# [Run 4] Iter 34 F1-illicit: 0.8193
# [Run 4] Iter 35 F1-illicit: 0.8238
# [Run 4] Iter 36 F1-illicit: 0.8166
# [Run 4] Iter 37 F1-illicit: 0.8223
# [Run 4] Iter 38 F1-illicit: 0.8178
# [Run 4] Iter 39 F1-illicit: 0.8220
# [Run 4] Iter 40 F1-illicit: 0.8248
# [Run 4] Iter 41 F1-illicit: 0.8286
# [Run 4] Iter 42 F1-illicit: 0.8266
# [Run 4] Iter 43 F1-illicit: 0.8266
# [Run 4] Iter 44 F1-illicit: 0.8234
# [Run 4] Iter 45 F1-illicit: 0.8187
# [Run 4] Iter 46 F1-illicit: 0.8156
# [Run 4] Iter 47 F1-illicit: 0.8233
# [Run 4] Iter 48 F1-illicit: 0.8266
# [Run 4] Iter 49 F1-illicit: 0.8178
# [Run 4] Iter 50 F1-illicit: 0.8156
# [Run 4] Iter 51 F1-illicit: 0.8173
# [Run 4] Iter 52 F1-illicit: 0.8229
# [Run 4] Iter 53 F1-illicit: 0.8192
# [Run 4] Iter 54 F1-illicit: 0.8208
# [Run 4] Iter 55 F1-illicit: 0.8244
# [Run 4] Iter 56 F1-illicit: 0.8224
# [Run 4] Iter 57 F1-illicit: 0.8205
# [Run 4] Iter 58 F1-illicit: 0.8271
# [Run 4] Iter 59 F1-illicit: 0.8182
# [Run 4] Iter 60 F1-illicit: 0.8242
#
# === Run 5/5 ===
# [Run 5] Iter 1 F1-illicit: 0.7361
# [Run 5] Iter 2 F1-illicit: 0.5111
# [Run 5] Iter 3 F1-illicit: 0.7128
# [Run 5] Iter 4 F1-illicit: 0.7922
# [Run 5] Iter 5 F1-illicit: 0.7077
# [Run 5] Iter 6 F1-illicit: 0.7974
# [Run 5] Iter 7 F1-illicit: 0.7783
# [Run 5] Iter 8 F1-illicit: 0.7052
# [Run 5] Iter 9 F1-illicit: 0.7774
# [Run 5] Iter 10 F1-illicit: 0.7593
# [Run 5] Iter 11 F1-illicit: 0.7658
# [Run 5] Iter 12 F1-illicit: 0.7657
# [Run 5] Iter 13 F1-illicit: 0.6692
# [Run 5] Iter 14 F1-illicit: 0.7738
# [Run 5] Iter 15 F1-illicit: 0.6855
# [Run 5] Iter 16 F1-illicit: 0.8189
# [Run 5] Iter 17 F1-illicit: 0.7895
# [Run 5] Iter 18 F1-illicit: 0.8041
# [Run 5] Iter 19 F1-illicit: 0.8081
# [Run 5] Iter 20 F1-illicit: 0.8187
# [Run 5] Iter 21 F1-illicit: 0.8134
# [Run 5] Iter 22 F1-illicit: 0.8202
# [Run 5] Iter 23 F1-illicit: 0.8179
# [Run 5] Iter 24 F1-illicit: 0.8153
# [Run 5] Iter 25 F1-illicit: 0.8185
# [Run 5] Iter 26 F1-illicit: 0.8161
# [Run 5] Iter 27 F1-illicit: 0.8149
# [Run 5] Iter 28 F1-illicit: 0.8119
# [Run 5] Iter 29 F1-illicit: 0.8174
# [Run 5] Iter 30 F1-illicit: 0.8103
# [Run 5] Iter 31 F1-illicit: 0.8163
# [Run 5] Iter 32 F1-illicit: 0.8254
# [Run 5] Iter 33 F1-illicit: 0.8192
# [Run 5] Iter 34 F1-illicit: 0.8208
# [Run 5] Iter 35 F1-illicit: 0.8251
# [Run 5] Iter 36 F1-illicit: 0.8197
# [Run 5] Iter 37 F1-illicit: 0.8195
# [Run 5] Iter 38 F1-illicit: 0.8197
# [Run 5] Iter 39 F1-illicit: 0.8177
# [Run 5] Iter 40 F1-illicit: 0.8188
# [Run 5] Iter 41 F1-illicit: 0.8195
# [Run 5] Iter 42 F1-illicit: 0.8309
# [Run 5] Iter 43 F1-illicit: 0.8253
# [Run 5] Iter 44 F1-illicit: 0.8233
# [Run 5] Iter 45 F1-illicit: 0.8204
# [Run 5] Iter 46 F1-illicit: 0.8242
# [Run 5] Iter 47 F1-illicit: 0.8187
# [Run 5] Iter 48 F1-illicit: 0.8215
# [Run 5] Iter 49 F1-illicit: 0.8180
# [Run 5] Iter 50 F1-illicit: 0.8211
# [Run 5] Iter 51 F1-illicit: 0.8219
# [Run 5] Iter 52 F1-illicit: 0.8215
# [Run 5] Iter 53 F1-illicit: 0.8217
# [Run 5] Iter 54 F1-illicit: 0.8206
# [Run 5] Iter 55 F1-illicit: 0.8228
# [Run 5] Iter 56 F1-illicit: 0.8193
# [Run 5] Iter 57 F1-illicit: 0.8266
# [Run 5] Iter 58 F1-illicit: 0.8225
# [Run 5] Iter 59 F1-illicit: 0.8227
# [Run 5] Iter 60 F1-illicit: 0.8180
#
# === Summary ===
# Median F1 per Iteration:
# Iteration 01 (50 samples): Median F1 = 0.7164
# Iteration 02 (100 samples): Median F1 = 0.6356
# Iteration 03 (150 samples): Median F1 = 0.7360
# Iteration 04 (200 samples): Median F1 = 0.7741
# Iteration 05 (250 samples): Median F1 = 0.7457
# Iteration 06 (300 samples): Median F1 = 0.7757
# Iteration 07 (350 samples): Median F1 = 0.7783
# Iteration 08 (400 samples): Median F1 = 0.8029
# Iteration 09 (450 samples): Median F1 = 0.7798
# Iteration 10 (500 samples): Median F1 = 0.7593
# Iteration 11 (550 samples): Median F1 = 0.7538
# Iteration 12 (600 samples): Median F1 = 0.7406
# Iteration 13 (650 samples): Median F1 = 0.7735
# Iteration 14 (700 samples): Median F1 = 0.7834
# Iteration 15 (750 samples): Median F1 = 0.7904
# Iteration 16 (800 samples): Median F1 = 0.8044
# Iteration 17 (850 samples): Median F1 = 0.7895
# Iteration 18 (900 samples): Median F1 = 0.7926
# Iteration 19 (950 samples): Median F1 = 0.8069
# Iteration 20 (1000 samples): Median F1 = 0.8099
# Iteration 21 (1050 samples): Median F1 = 0.8110
# Iteration 22 (1100 samples): Median F1 = 0.8112
# Iteration 23 (1150 samples): Median F1 = 0.8083
# Iteration 24 (1200 samples): Median F1 = 0.8153
# Iteration 25 (1250 samples): Median F1 = 0.8185
# Iteration 26 (1300 samples): Median F1 = 0.8135
# Iteration 27 (1350 samples): Median F1 = 0.8149
# Iteration 28 (1400 samples): Median F1 = 0.8124
# Iteration 29 (1450 samples): Median F1 = 0.8205
# Iteration 30 (1500 samples): Median F1 = 0.8220
# Iteration 31 (1550 samples): Median F1 = 0.8219
# Iteration 32 (1600 samples): Median F1 = 0.8235
# Iteration 33 (1650 samples): Median F1 = 0.8235
# Iteration 34 (1700 samples): Median F1 = 0.8208
# Iteration 35 (1750 samples): Median F1 = 0.8251
# Iteration 36 (1800 samples): Median F1 = 0.8197
# Iteration 37 (1850 samples): Median F1 = 0.8201
# Iteration 38 (1900 samples): Median F1 = 0.8215
# Iteration 39 (1950 samples): Median F1 = 0.8220
# Iteration 40 (2000 samples): Median F1 = 0.8210
# Iteration 41 (2050 samples): Median F1 = 0.8216
# Iteration 42 (2100 samples): Median F1 = 0.8261
# Iteration 43 (2150 samples): Median F1 = 0.8212
# Iteration 44 (2200 samples): Median F1 = 0.8234
# Iteration 45 (2250 samples): Median F1 = 0.8204
# Iteration 46 (2300 samples): Median F1 = 0.8217
# Iteration 47 (2350 samples): Median F1 = 0.8233
# Iteration 48 (2400 samples): Median F1 = 0.8252
# Iteration 49 (2450 samples): Median F1 = 0.8217
# Iteration 50 (2500 samples): Median F1 = 0.8193
# Iteration 51 (2550 samples): Median F1 = 0.8203
# Iteration 52 (2600 samples): Median F1 = 0.8220
# Iteration 53 (2650 samples): Median F1 = 0.8199
# Iteration 54 (2700 samples): Median F1 = 0.8206
# Iteration 55 (2750 samples): Median F1 = 0.8238
# Iteration 56 (2800 samples): Median F1 = 0.8224
# Iteration 57 (2850 samples): Median F1 = 0.8219
# Iteration 58 (2900 samples): Median F1 = 0.8225
# Iteration 59 (2950 samples): Median F1 = 0.8227
# Iteration 60 (3000 samples): Median F1 = 0.8225
#
# Final Median F1 (illicit): 0.8225
# Average Warm-up size: 50
# Average Active Learning size: 3000
# Average Final Training set size: 3050

# %% [markdown]
# # Full Python Code: Active Learning (IF + Uncertainty Sampling + XGBoost)

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import IsolationForest
from sklearn.metrics import f1_score
from xgboost import XGBClassifier
import matplotlib.pyplot as plt

# Load data
labeled_df = pd.read_csv("elliptic_txs_features_labeled.csv")

# Split train/test by time_step
train_df = labeled_df[labeled_df['time_step'] <= 34].reset_index(drop=True)
test_df = labeled_df[labeled_df['time_step'] >= 35].reset_index(drop=True)

X_test = test_df.drop(columns=['txId', 'time_step', 'class'])
y_test = (test_df['class'] == 1).astype(int)

feature_columns = [col for col in train_df.columns if col.startswith('feature_') or col.startswith('f')]

# Config
batch_size = 50
max_iterations = 60
N_runs = 5
all_f1_scores = []
warmup_sizes = []
active_sizes = []

for run in range(N_runs):
    print(f"\n=== Run {run+1}/{N_runs} ===")
    unlabeled_pool = train_df.copy()
    labeled_pool = pd.DataFrame(columns=train_df.columns)
    f1_scores = []

    # Warm-up via Isolation Forest
    iso_forest = IsolationForest(n_estimators=25, random_state=run + 42)
    iso_forest.fit(unlabeled_pool[feature_columns])
    scores = -iso_forest.score_samples(unlabeled_pool[feature_columns])
    unlabeled_pool['anomaly_score'] = scores
    unlabeled_pool = unlabeled_pool.sort_values(by='anomaly_score', ascending=False).reset_index(drop=True)

    found_illicit = False
    pointer = 0
    while not found_illicit and pointer < len(unlabeled_pool):
        batch = unlabeled_pool.iloc[pointer:pointer + batch_size]
        labeled_pool = pd.concat([labeled_pool, batch], ignore_index=True)
        pointer += batch_size
        found_illicit = (labeled_pool['class'] == 1).sum() > 0

    warmup_size = len(labeled_pool)
    warmup_sizes.append(warmup_size)
    unlabeled_pool = unlabeled_pool.iloc[pointer:].drop(columns='anomaly_score').reset_index(drop=True)

    # Active Learning Loop
    iteration = 1
    while len(unlabeled_pool) > 0 and iteration <= max_iterations:
        X_train = labeled_pool[feature_columns]
        y_train = (labeled_pool['class'] == 1).astype(int)

        model = XGBClassifier(eval_metric='logloss', random_state=run + 1)
        model.fit(X_train, y_train)

        y_pred = model.predict(X_test)
        f1 = f1_score(y_test, y_pred, pos_label=1)
        f1_scores.append(f1)
        print(f"[Run {run+1}] Iter {iteration} F1-illicit: {f1:.4f}")

        proba = model.predict_proba(unlabeled_pool[feature_columns])[:, 1]
        uncertainty = np.abs(proba - 0.5)
        select_idx = np.argsort(uncertainty)[:batch_size]

        new_batch = unlabeled_pool.iloc[select_idx]
        labeled_pool = pd.concat([labeled_pool, new_batch], ignore_index=True)
        unlabeled_pool = unlabeled_pool.drop(unlabeled_pool.index[select_idx]).reset_index(drop=True)

        iteration += 1

    all_f1_scores.append(f1_scores)
    active_sizes.append(len(f1_scores) * batch_size)

# --- Evaluation ---
max_len = max(len(scores) for scores in all_f1_scores)
f1_matrix = np.full((N_runs, max_len), np.nan)
for i, scores in enumerate(all_f1_scores):
    f1_matrix[i, :len(scores)] = scores

median_f1_per_iter = np.nanmedian(f1_matrix, axis=0)
final_median_f1 = np.nanmedian([scores[-1] for scores in all_f1_scores if len(scores) == max_len])

# --- Output ---
print("\n=== Summary ===")
print("Median F1 per Iteration:")
for i, f1 in enumerate(median_f1_per_iter):
    print(f"Iteration {i+1:02d} ({(i+1)*batch_size} samples): Median F1 = {f1:.4f}")

print(f"\nFinal Median F1 (illicit): {round(final_median_f1, 4)}")
print("Average Warm-up size:", int(np.mean(warmup_sizes)))
print("Average Active Learning size:", int(np.mean(active_sizes)))
print("Average Final Training set size:", int(np.mean(np.array(warmup_sizes) + np.array(active_sizes))))

# --- Plot ---
plt.figure(figsize=(8, 5))
plt.plot(np.arange(1, len(median_f1_per_iter)+1)*batch_size, median_f1_per_iter, label='Median F1', marker='o')
plt.xlabel("Number of Labeled Samples")
plt.ylabel("Illicit F1-score")
plt.title("Active Learning: IF + Uncertainty Sampling + XGBoost")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# === Run 1/5 ===
# C:\Users\frank\AppData\Local\Temp\ipykernel_6856\2928542305.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   labeled_pool = pd.concat([labeled_pool, batch], ignore_index=True)
# [Run 1] Iter 1 F1-illicit: 0.0000
# [Run 1] Iter 2 F1-illicit: 0.3665
# [Run 1] Iter 3 F1-illicit: 0.7208
# [Run 1] Iter 4 F1-illicit: 0.6618
# [Run 1] Iter 5 F1-illicit: 0.6362
# [Run 1] Iter 6 F1-illicit: 0.7148
# [Run 1] Iter 7 F1-illicit: 0.7162
# [Run 1] Iter 8 F1-illicit: 0.7666
# [Run 1] Iter 9 F1-illicit: 0.7474
# [Run 1] Iter 10 F1-illicit: 0.7667
# [Run 1] Iter 11 F1-illicit: 0.7900
# [Run 1] Iter 12 F1-illicit: 0.7685
# [Run 1] Iter 13 F1-illicit: 0.7975
# [Run 1] Iter 14 F1-illicit: 0.7956
# [Run 1] Iter 15 F1-illicit: 0.7918
# [Run 1] Iter 16 F1-illicit: 0.7775
# [Run 1] Iter 17 F1-illicit: 0.7920
# [Run 1] Iter 18 F1-illicit: 0.7785
# [Run 1] Iter 19 F1-illicit: 0.7782
# [Run 1] Iter 20 F1-illicit: 0.7875
# [Run 1] Iter 21 F1-illicit: 0.7958
# [Run 1] Iter 22 F1-illicit: 0.7998
# [Run 1] Iter 23 F1-illicit: 0.8244
# [Run 1] Iter 24 F1-illicit: 0.8113
# [Run 1] Iter 25 F1-illicit: 0.8149
# [Run 1] Iter 26 F1-illicit: 0.8139
# [Run 1] Iter 27 F1-illicit: 0.8197
# [Run 1] Iter 28 F1-illicit: 0.8119
# [Run 1] Iter 29 F1-illicit: 0.8145
# [Run 1] Iter 30 F1-illicit: 0.8093
# [Run 1] Iter 31 F1-illicit: 0.8021
# [Run 1] Iter 32 F1-illicit: 0.7998
# [Run 1] Iter 33 F1-illicit: 0.7946
# [Run 1] Iter 34 F1-illicit: 0.8035
# [Run 1] Iter 35 F1-illicit: 0.8091
# [Run 1] Iter 36 F1-illicit: 0.8065
# [Run 1] Iter 37 F1-illicit: 0.8124
# [Run 5] Iter 12 F1-illicit: 0.7958
# [Run 5] Iter 13 F1-illicit: 0.7861
# [Run 5] Iter 14 F1-illicit: 0.8099
# [Run 5] Iter 15 F1-illicit: 0.8071
# [Run 5] Iter 16 F1-illicit: 0.8032
# [Run 5] Iter 17 F1-illicit: 0.8114
# [Run 5] Iter 18 F1-illicit: 0.8028
# [Run 5] Iter 19 F1-illicit: 0.8053
# [Run 5] Iter 20 F1-illicit: 0.8028
# [Run 5] Iter 21 F1-illicit: 0.7884
# [Run 5] Iter 22 F1-illicit: 0.8065
# [Run 5] Iter 23 F1-illicit: 0.7942
# [Run 5] Iter 24 F1-illicit: 0.7996
# [Run 5] Iter 25 F1-illicit: 0.8115
# [Run 5] Iter 26 F1-illicit: 0.8104
# [Run 5] Iter 27 F1-illicit: 0.8133
# [Run 5] Iter 28 F1-illicit: 0.8071
# [Run 5] Iter 29 F1-illicit: 0.8111
# [Run 5] Iter 30 F1-illicit: 0.8122
# [Run 5] Iter 31 F1-illicit: 0.8189
# [Run 5] Iter 32 F1-illicit: 0.8110
# [Run 5] Iter 33 F1-illicit: 0.8157
# [Run 5] Iter 34 F1-illicit: 0.8154
# [Run 5] Iter 35 F1-illicit: 0.8102
# [Run 5] Iter 36 F1-illicit: 0.8165
# [Run 5] Iter 37 F1-illicit: 0.8114
# [Run 5] Iter 38 F1-illicit: 0.8053
# [Run 5] Iter 39 F1-illicit: 0.8094
# [Run 5] Iter 40 F1-illicit: 0.8082
# [Run 5] Iter 41 F1-illicit: 0.8010
# [Run 5] Iter 42 F1-illicit: 0.8085
# [Run 5] Iter 43 F1-illicit: 0.8168
# [Run 5] Iter 44 F1-illicit: 0.8018
# [Run 5] Iter 45 F1-illicit: 0.8090
# [Run 5] Iter 46 F1-illicit: 0.8154
# [Run 5] Iter 47 F1-illicit: 0.8202
# [Run 5] Iter 48 F1-illicit: 0.8122
# [Run 5] Iter 49 F1-illicit: 0.8105
# [Run 5] Iter 50 F1-illicit: 0.8179
# [Run 5] Iter 51 F1-illicit: 0.8156
# [Run 5] Iter 52 F1-illicit: 0.8141
# [Run 5] Iter 53 F1-illicit: 0.8166
# [Run 5] Iter 54 F1-illicit: 0.8135
# [Run 5] Iter 55 F1-illicit: 0.8033
# [Run 5] Iter 56 F1-illicit: 0.8128
# [Run 5] Iter 57 F1-illicit: 0.8022
# [Run 5] Iter 58 F1-illicit: 0.8097
# [Run 5] Iter 59 F1-illicit: 0.8158
# [Run 5] Iter 60 F1-illicit: 0.8197
#
# === Summary ===
# Median F1 per Iteration:
# Iteration 01 (50 samples): Median F1 = 0.0000
# Iteration 02 (100 samples): Median F1 = 0.0088
# Iteration 03 (150 samples): Median F1 = 0.1816
# Iteration 04 (200 samples): Median F1 = 0.5401
# Iteration 05 (250 samples): Median F1 = 0.6042
# Iteration 06 (300 samples): Median F1 = 0.6028
# Iteration 07 (350 samples): Median F1 = 0.6684
# Iteration 08 (400 samples): Median F1 = 0.7003
# Iteration 09 (450 samples): Median F1 = 0.7351
# Iteration 10 (500 samples): Median F1 = 0.7444
# Iteration 11 (550 samples): Median F1 = 0.7833
# Iteration 12 (600 samples): Median F1 = 0.7908
# Iteration 13 (650 samples): Median F1 = 0.7879
# Iteration 14 (700 samples): Median F1 = 0.7992
# Iteration 15 (750 samples): Median F1 = 0.8047
# Iteration 16 (800 samples): Median F1 = 0.7978
# Iteration 17 (850 samples): Median F1 = 0.8063
# Iteration 18 (900 samples): Median F1 = 0.8053
# Iteration 19 (950 samples): Median F1 = 0.8047
# Iteration 20 (1000 samples): Median F1 = 0.8008
# Iteration 21 (1050 samples): Median F1 = 0.7955
# Iteration 22 (1100 samples): Median F1 = 0.8043
# Iteration 23 (1150 samples): Median F1 = 0.8108
# Iteration 24 (1200 samples): Median F1 = 0.8113
# Iteration 25 (1250 samples): Median F1 = 0.8059
# Iteration 26 (1300 samples): Median F1 = 0.8068
# Iteration 27 (1350 samples): Median F1 = 0.8123
# Iteration 28 (1400 samples): Median F1 = 0.8077
# Iteration 29 (1450 samples): Median F1 = 0.8097
# Iteration 30 (1500 samples): Median F1 = 0.8093
# Iteration 31 (1550 samples): Median F1 = 0.8072
# Iteration 32 (1600 samples): Median F1 = 0.8094
# Iteration 33 (1650 samples): Median F1 = 0.8109
# Iteration 34 (1700 samples): Median F1 = 0.8099
# Iteration 35 (1750 samples): Median F1 = 0.8091
# Iteration 36 (1800 samples): Median F1 = 0.8120
# Iteration 37 (1850 samples): Median F1 = 0.8103
# Iteration 38 (1900 samples): Median F1 = 0.8095
# Iteration 39 (1950 samples): Median F1 = 0.8096
# Iteration 40 (2000 samples): Median F1 = 0.8101
# Iteration 41 (2050 samples): Median F1 = 0.8055
# Iteration 42 (2100 samples): Median F1 = 0.8072
# Iteration 43 (2150 samples): Median F1 = 0.8107
# Iteration 44 (2200 samples): Median F1 = 0.8088
# Iteration 45 (2250 samples): Median F1 = 0.8090
# Iteration 46 (2300 samples): Median F1 = 0.8127
# Iteration 47 (2350 samples): Median F1 = 0.8087
# Iteration 48 (2400 samples): Median F1 = 0.8122
# Iteration 49 (2450 samples): Median F1 = 0.8078
# Iteration 50 (2500 samples): Median F1 = 0.8078
# Iteration 51 (2550 samples): Median F1 = 0.8107
# Iteration 52 (2600 samples): Median F1 = 0.8141
# Iteration 53 (2650 samples): Median F1 = 0.8130
# Iteration 54 (2700 samples): Median F1 = 0.8135
# Iteration 55 (2750 samples): Median F1 = 0.8085
# Iteration 56 (2800 samples): Median F1 = 0.8148
# Iteration 57 (2850 samples): Median F1 = 0.8137
# Iteration 58 (2900 samples): Median F1 = 0.8098
# Iteration 59 (2950 samples): Median F1 = 0.8149
# Iteration 60 (3000 samples): Median F1 = 0.8160
#
# Final Median F1 (illicit): 0.816
# Average Warm-up size: 2050
# Average Active Learning size: 3000
# Average Final Training set size: 5050

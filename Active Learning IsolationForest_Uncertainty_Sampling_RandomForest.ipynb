# %% [markdown]
# # Active Learning RandomSampling_Uncertainty_Sampling_RandomForest

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import IsolationForest, RandomForestClassifier
from sklearn.metrics import f1_score
import matplotlib.pyplot as plt

# Load data
labeled_df = pd.read_csv("elliptic_txs_features_labeled.csv")

# Split train/test by time_step
train_df = labeled_df[labeled_df['time_step'] <= 34].reset_index(drop=True)
test_df = labeled_df[labeled_df['time_step'] >= 35].reset_index(drop=True)

X_test = test_df.drop(columns=['txId', 'time_step', 'class'])
y_test = (test_df['class'] == 1).astype(int)

feature_columns = [col for col in train_df.columns if col.startswith('feature_') or col.startswith('f')]

# Config
batch_size = 50
max_iterations = 60
N_runs = 5
all_f1_scores = []
warmup_sizes = []
active_sizes = []

for run in range(N_runs):
    print(f"\n=== Run {run+1}/{N_runs} ===")
    unlabeled_pool = train_df.copy().reset_index(drop=True)
    labeled_pool = pd.DataFrame(columns=train_df.columns)

    # --- Warm-up via Isolation Forest ---
    iso_forest = IsolationForest(n_estimators=25, random_state=run + 42)
    iso_forest.fit(unlabeled_pool[feature_columns])
    scores = -iso_forest.score_samples(unlabeled_pool[feature_columns])
    unlabeled_pool['anomaly_score'] = scores
    unlabeled_pool = unlabeled_pool.sort_values(by='anomaly_score', ascending=False).reset_index(drop=True)

    pointer = 0
    found_illicit = False
    while not found_illicit and pointer < len(unlabeled_pool):
        batch = unlabeled_pool.iloc[pointer:pointer + batch_size]
        labeled_pool = pd.concat([labeled_pool, batch], ignore_index=True)
        pointer += batch_size
        found_illicit = (labeled_pool['class'] == 1).sum() > 0

    warmup_size = len(labeled_pool)
    warmup_sizes.append(warmup_size)
    unlabeled_pool = unlabeled_pool.iloc[pointer:].drop(columns='anomaly_score').reset_index(drop=True)

    f1_scores = []

    # --- Active Learning Loop (Uncertainty Sampling) ---
    for iteration in range(1, max_iterations + 1):
        X_train = labeled_pool[feature_columns]
        y_train = (labeled_pool['class'] == 1).astype(int)

        model = RandomForestClassifier(
            n_estimators=100,
            max_depth=10,
            random_state=run,
            n_jobs=-1
        )
        model.fit(X_train, y_train)

        y_pred = model.predict(X_test)
        f1 = f1_score(y_test, y_pred, pos_label=1)
        f1_scores.append(f1)
        print(f"[Run {run+1}] Iter {iteration} F1-illicit: {f1:.4f}")

        # --- Uncertainty sampling ---
        proba = model.predict_proba(unlabeled_pool[feature_columns])[:, 1]
        uncertainty = np.abs(proba - 0.5)
        select_idx = np.argsort(uncertainty)[:batch_size]

        new_batch = unlabeled_pool.iloc[select_idx]
        labeled_pool = pd.concat([labeled_pool, new_batch], ignore_index=True)
        unlabeled_pool = unlabeled_pool.drop(unlabeled_pool.index[select_idx]).reset_index(drop=True)

        if len(unlabeled_pool) == 0:
            break

    all_f1_scores.append(f1_scores)
    active_sizes.append(len(f1_scores) * batch_size)

# --- Evaluation ---
max_len = max(len(scores) for scores in all_f1_scores)
f1_matrix = np.full((N_runs, max_len), np.nan)
for i, scores in enumerate(all_f1_scores):
    f1_matrix[i, :len(scores)] = scores

median_f1_per_iter = np.nanmedian(f1_matrix, axis=0)
final_median_f1 = np.nanmedian([scores[-1] for scores in all_f1_scores if len(scores) == max_len])

# --- Output ---
print("\n=== Summary ===")
print("Median F1 per Iteration:")
for i, f1 in enumerate(median_f1_per_iter):
    print(f"Iteration {i+1:02d} ({(i+1)*batch_size} samples): Median F1 = {f1:.4f}")

print(f"\nFinal Median F1 (illicit): {round(final_median_f1, 4)}")
print("Average Warm-up size:", int(np.mean(warmup_sizes)))
print("Average Active Learning size:", int(np.mean(active_sizes)))
print("Average Final Training set size:", int(np.mean(np.array(warmup_sizes) + np.array(active_sizes))))

# --- Plot ---
plt.figure(figsize=(8, 5))
plt.plot(np.arange(1, len(median_f1_per_iter)+1)*batch_size, median_f1_per_iter, label='Median F1', marker='o')
plt.xlabel("Number of Labeled Samples")
plt.ylabel("Illicit F1-score")
plt.title("Active Learning: IF + Uncertainty Sampling + Random Forest")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# === Run 1/5 ===
# C:\Users\frank\AppData\Local\Temp\ipykernel_12920\1556642997.py:43: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   labeled_pool = pd.concat([labeled_pool, batch], ignore_index=True)
# [Run 1] Iter 1 F1-illicit: 0.0000
# [Run 1] Iter 2 F1-illicit: 0.0000
# [Run 1] Iter 3 F1-illicit: 0.0000
# [Run 1] Iter 4 F1-illicit: 0.0000
# [Run 1] Iter 5 F1-illicit: 0.0000
# [Run 1] Iter 6 F1-illicit: 0.0000
# [Run 1] Iter 7 F1-illicit: 0.7595
# [Run 1] Iter 8 F1-illicit: 0.7269
# [Run 1] Iter 9 F1-illicit: 0.7836
# [Run 1] Iter 10 F1-illicit: 0.7835
# [Run 1] Iter 11 F1-illicit: 0.8129
# [Run 1] Iter 12 F1-illicit: 0.8106
# [Run 1] Iter 13 F1-illicit: 0.8147
# [Run 1] Iter 14 F1-illicit: 0.7695
# [Run 1] Iter 15 F1-illicit: 0.7625
# [Run 1] Iter 16 F1-illicit: 0.7611
# [Run 1] Iter 17 F1-illicit: 0.8043
# [Run 1] Iter 18 F1-illicit: 0.7886
# [Run 1] Iter 19 F1-illicit: 0.8164
# [Run 1] Iter 20 F1-illicit: 0.8079
# [Run 1] Iter 21 F1-illicit: 0.8012
# [Run 1] Iter 22 F1-illicit: 0.8094
# [Run 1] Iter 23 F1-illicit: 0.8098
# [Run 1] Iter 24 F1-illicit: 0.8192
# [Run 1] Iter 25 F1-illicit: 0.8126
# [Run 1] Iter 26 F1-illicit: 0.8140
# [Run 1] Iter 27 F1-illicit: 0.8190
# [Run 1] Iter 28 F1-illicit: 0.8177
# [Run 1] Iter 29 F1-illicit: 0.8163
# [Run 1] Iter 30 F1-illicit: 0.8214
# [Run 1] Iter 31 F1-illicit: 0.8147
# [Run 1] Iter 32 F1-illicit: 0.8166
# [Run 1] Iter 33 F1-illicit: 0.8211
# [Run 1] Iter 34 F1-illicit: 0.8153
# [Run 1] Iter 35 F1-illicit: 0.8228
# [Run 5] Iter 11 F1-illicit: 0.8029
# [Run 5] Iter 12 F1-illicit: 0.7927
# [Run 5] Iter 13 F1-illicit: 0.7269
# [Run 5] Iter 14 F1-illicit: 0.7914
# [Run 5] Iter 15 F1-illicit: 0.7322
# [Run 5] Iter 16 F1-illicit: 0.7751
# [Run 5] Iter 17 F1-illicit: 0.7679
# [Run 5] Iter 18 F1-illicit: 0.7969
# [Run 5] Iter 19 F1-illicit: 0.7874
# [Run 5] Iter 20 F1-illicit: 0.7867
# [Run 5] Iter 21 F1-illicit: 0.7998
# [Run 5] Iter 22 F1-illicit: 0.8219
# [Run 5] Iter 23 F1-illicit: 0.8093
# [Run 5] Iter 24 F1-illicit: 0.8241
# [Run 5] Iter 25 F1-illicit: 0.8194
# [Run 5] Iter 26 F1-illicit: 0.8227
# [Run 5] Iter 27 F1-illicit: 0.8260
# [Run 5] Iter 28 F1-illicit: 0.8243
# [Run 5] Iter 29 F1-illicit: 0.8294
# [Run 5] Iter 30 F1-illicit: 0.8222
# [Run 5] Iter 31 F1-illicit: 0.8264
# [Run 5] Iter 32 F1-illicit: 0.8292
# [Run 5] Iter 33 F1-illicit: 0.8264
# [Run 5] Iter 34 F1-illicit: 0.8220
# [Run 5] Iter 35 F1-illicit: 0.8215
# [Run 5] Iter 36 F1-illicit: 0.8219
# [Run 5] Iter 37 F1-illicit: 0.8258
# [Run 5] Iter 38 F1-illicit: 0.8192
# [Run 5] Iter 39 F1-illicit: 0.8249
# [Run 5] Iter 40 F1-illicit: 0.8241
# [Run 5] Iter 41 F1-illicit: 0.8189
# [Run 5] Iter 42 F1-illicit: 0.8256
# [Run 5] Iter 43 F1-illicit: 0.8221
# [Run 5] Iter 44 F1-illicit: 0.8178
# [Run 5] Iter 45 F1-illicit: 0.8256
# [Run 5] Iter 46 F1-illicit: 0.8223
# [Run 5] Iter 47 F1-illicit: 0.8269
# [Run 5] Iter 48 F1-illicit: 0.8208
# [Run 5] Iter 49 F1-illicit: 0.8262
# [Run 5] Iter 50 F1-illicit: 0.8254
# [Run 5] Iter 51 F1-illicit: 0.8236
# [Run 5] Iter 52 F1-illicit: 0.8221
# [Run 5] Iter 53 F1-illicit: 0.8225
# [Run 5] Iter 54 F1-illicit: 0.8198
# [Run 5] Iter 55 F1-illicit: 0.8240
# [Run 5] Iter 56 F1-illicit: 0.8196
# [Run 5] Iter 57 F1-illicit: 0.8243
# [Run 5] Iter 58 F1-illicit: 0.8251
# [Run 5] Iter 59 F1-illicit: 0.8266
# [Run 5] Iter 60 F1-illicit: 0.8252
#
# === Summary ===
# Median F1 per Iteration:
# Iteration 01 (50 samples): Median F1 = 0.0000
# Iteration 02 (100 samples): Median F1 = 0.0522
# Iteration 03 (150 samples): Median F1 = 0.6407
# Iteration 04 (200 samples): Median F1 = 0.7387
# Iteration 05 (250 samples): Median F1 = 0.7443
# Iteration 06 (300 samples): Median F1 = 0.7876
# Iteration 07 (350 samples): Median F1 = 0.7779
# Iteration 08 (400 samples): Median F1 = 0.7938
# Iteration 09 (450 samples): Median F1 = 0.7836
# Iteration 10 (500 samples): Median F1 = 0.7835
# Iteration 11 (550 samples): Median F1 = 0.8029
# Iteration 12 (600 samples): Median F1 = 0.7927
# Iteration 13 (650 samples): Median F1 = 0.7946
# Iteration 14 (700 samples): Median F1 = 0.7914
# Iteration 15 (750 samples): Median F1 = 0.7817
# Iteration 16 (800 samples): Median F1 = 0.8037
# Iteration 17 (850 samples): Median F1 = 0.8100
# Iteration 18 (900 samples): Median F1 = 0.8035
# Iteration 19 (950 samples): Median F1 = 0.7976
# Iteration 20 (1000 samples): Median F1 = 0.8085
# Iteration 21 (1050 samples): Median F1 = 0.8012
# Iteration 22 (1100 samples): Median F1 = 0.8179
# Iteration 23 (1150 samples): Median F1 = 0.8138
# Iteration 24 (1200 samples): Median F1 = 0.8178
# Iteration 25 (1250 samples): Median F1 = 0.8201
# Iteration 26 (1300 samples): Median F1 = 0.8189
# Iteration 27 (1350 samples): Median F1 = 0.8219
# Iteration 28 (1400 samples): Median F1 = 0.8243
# Iteration 29 (1450 samples): Median F1 = 0.8220
# Iteration 30 (1500 samples): Median F1 = 0.8214
# Iteration 31 (1550 samples): Median F1 = 0.8253
# Iteration 32 (1600 samples): Median F1 = 0.8270
# Iteration 33 (1650 samples): Median F1 = 0.8264
# Iteration 34 (1700 samples): Median F1 = 0.8232
# Iteration 35 (1750 samples): Median F1 = 0.8237
# Iteration 36 (1800 samples): Median F1 = 0.8230
# Iteration 37 (1850 samples): Median F1 = 0.8258
# Iteration 38 (1900 samples): Median F1 = 0.8275
# Iteration 39 (1950 samples): Median F1 = 0.8245
# Iteration 40 (2000 samples): Median F1 = 0.8238
# Iteration 41 (2050 samples): Median F1 = 0.8237
# Iteration 42 (2100 samples): Median F1 = 0.8224
# Iteration 43 (2150 samples): Median F1 = 0.8202
# Iteration 44 (2200 samples): Median F1 = 0.8233
# Iteration 45 (2250 samples): Median F1 = 0.8229
# Iteration 46 (2300 samples): Median F1 = 0.8223
# Iteration 47 (2350 samples): Median F1 = 0.8242
# Iteration 48 (2400 samples): Median F1 = 0.8208
# Iteration 49 (2450 samples): Median F1 = 0.8211
# Iteration 50 (2500 samples): Median F1 = 0.8236
# Iteration 51 (2550 samples): Median F1 = 0.8221
# Iteration 52 (2600 samples): Median F1 = 0.8221
# Iteration 53 (2650 samples): Median F1 = 0.8225
# Iteration 54 (2700 samples): Median F1 = 0.8209
# Iteration 55 (2750 samples): Median F1 = 0.8240
# Iteration 56 (2800 samples): Median F1 = 0.8234
# Iteration 57 (2850 samples): Median F1 = 0.8243
# Iteration 58 (2900 samples): Median F1 = 0.8251
# Iteration 59 (2950 samples): Median F1 = 0.8266
# Iteration 60 (3000 samples): Median F1 = 0.8249
#
# Final Median F1 (illicit): 0.8249
# Average Warm-up size: 2050
# Average Active Learning size: 3000
# Average Final Training set size: 5050

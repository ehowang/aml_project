# %% [markdown]
# # Active Learning: IF + Uncertainty Sampling + Logistic Regression

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import IsolationForest
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score
import matplotlib.pyplot as plt

# Load data
labeled_df = pd.read_csv("elliptic_txs_features_labeled.csv")

# Split train/test by time_step
train_df = labeled_df[labeled_df['time_step'] <= 34].reset_index(drop=True)
test_df = labeled_df[labeled_df['time_step'] >= 35].reset_index(drop=True)

X_test = test_df.drop(columns=['txId', 'time_step', 'class'])
y_test = (test_df['class'] == 1).astype(int)

feature_columns = [col for col in train_df.columns if col.startswith('feature_') or col.startswith('f')]

# Config
batch_size = 50
max_iterations = 60
N_runs = 5
all_f1_scores = []
warmup_sizes = []
active_sizes = []

for run in range(N_runs):
    print(f"\n=== Run {run+1}/{N_runs} ===")
    unlabeled_pool = train_df.copy()
    labeled_pool = pd.DataFrame(columns=train_df.columns)
    f1_scores = []

    # Warm-up via Isolation Forest
    iso_forest = IsolationForest(n_estimators=25, random_state=run + 42)
    iso_forest.fit(unlabeled_pool[feature_columns])
    scores = -iso_forest.score_samples(unlabeled_pool[feature_columns])
    unlabeled_pool['anomaly_score'] = scores
    unlabeled_pool = unlabeled_pool.sort_values(by='anomaly_score', ascending=False).reset_index(drop=True)

    found_illicit = False
    pointer = 0
    while not found_illicit and pointer < len(unlabeled_pool):
        batch = unlabeled_pool.iloc[pointer:pointer + batch_size]
        labeled_pool = pd.concat([labeled_pool, batch], ignore_index=True)
        pointer += batch_size
        found_illicit = (labeled_pool['class'] == 1).sum() > 0

    warmup_size = len(labeled_pool)
    warmup_sizes.append(warmup_size)
    unlabeled_pool = unlabeled_pool.iloc[pointer:].drop(columns='anomaly_score').reset_index(drop=True)

    # Active Learning Loop
    iteration = 1
    while len(unlabeled_pool) > 0 and iteration <= max_iterations:
        X_train = labeled_pool[feature_columns]
        y_train = (labeled_pool['class'] == 1).astype(int)

        model = LogisticRegression(max_iter=300, solver='liblinear', random_state=run + 1)
        model.fit(X_train, y_train)

        y_pred = model.predict(X_test)
        f1 = f1_score(y_test, y_pred, pos_label=1)
        f1_scores.append(f1)
        print(f"[Run {run+1}] Iter {iteration} F1-illicit: {f1:.4f}")

        proba = model.predict_proba(unlabeled_pool[feature_columns])[:, 1]
        uncertainty = np.abs(proba - 0.5)
        select_idx = np.argsort(uncertainty)[:batch_size]

        new_batch = unlabeled_pool.iloc[select_idx]
        labeled_pool = pd.concat([labeled_pool, new_batch], ignore_index=True)
        unlabeled_pool = unlabeled_pool.drop(unlabeled_pool.index[select_idx]).reset_index(drop=True)

        iteration += 1

    all_f1_scores.append(f1_scores)
    active_sizes.append(len(f1_scores) * batch_size)

# --- Evaluation ---
max_len = max(len(scores) for scores in all_f1_scores)
f1_matrix = np.full((N_runs, max_len), np.nan)
for i, scores in enumerate(all_f1_scores):
    f1_matrix[i, :len(scores)] = scores

median_f1_per_iter = np.nanmedian(f1_matrix, axis=0)
final_median_f1 = np.nanmedian([scores[-1] for scores in all_f1_scores if len(scores) == max_len])

# --- Output ---
print("\n=== Summary ===")
print("Median F1 per Iteration:")
for i, f1 in enumerate(median_f1_per_iter):
    print(f"Iteration {i+1:02d} ({(i+1)*batch_size} samples): Median F1 = {f1:.4f}")

print(f"\nFinal Median F1 (illicit): {round(final_median_f1, 4)}")
print("Average Warm-up size:", int(np.mean(warmup_sizes)))
print("Average Active Learning size:", int(np.mean(active_sizes)))
print("Average Final Training set size:", int(np.mean(np.array(warmup_sizes) + np.array(active_sizes))))

# --- Plot ---
plt.figure(figsize=(8, 5))
plt.plot(np.arange(1, len(median_f1_per_iter)+1)*batch_size, median_f1_per_iter, label='Median F1', marker='o')
plt.xlabel("Number of Labeled Samples")
plt.ylabel("Illicit F1-score")
plt.title("Active Learning: IF + Uncertainty Sampling + Logistic Regression")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# === Run 1/5 ===
# C:\Users\frank\AppData\Local\Temp\ipykernel_16632\1564263152.py:45: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   labeled_pool = pd.concat([labeled_pool, batch], ignore_index=True)
# [Run 1] Iter 1 F1-illicit: 0.1932
# [Run 1] Iter 2 F1-illicit: 0.2049
# [Run 1] Iter 3 F1-illicit: 0.2185
# [Run 1] Iter 4 F1-illicit: 0.2455
# [Run 1] Iter 5 F1-illicit: 0.2620
# [Run 1] Iter 6 F1-illicit: 0.2663
# [Run 1] Iter 7 F1-illicit: 0.2803
# [Run 1] Iter 8 F1-illicit: 0.2876
# [Run 1] Iter 9 F1-illicit: 0.2985
# [Run 1] Iter 10 F1-illicit: 0.3256
# [Run 1] Iter 11 F1-illicit: 0.3388
# [Run 1] Iter 12 F1-illicit: 0.3478
# [Run 1] Iter 13 F1-illicit: 0.3912
# [Run 1] Iter 14 F1-illicit: 0.4084
# [Run 1] Iter 15 F1-illicit: 0.4060
# [Run 1] Iter 16 F1-illicit: 0.3967
# [Run 1] Iter 17 F1-illicit: 0.4108
# [Run 1] Iter 18 F1-illicit: 0.4177
# [Run 1] Iter 19 F1-illicit: 0.4176
# [Run 1] Iter 20 F1-illicit: 0.4240
# [Run 1] Iter 21 F1-illicit: 0.4423
# [Run 1] Iter 22 F1-illicit: 0.4578
# [Run 1] Iter 23 F1-illicit: 0.4717
# [Run 1] Iter 24 F1-illicit: 0.4716
# [Run 1] Iter 25 F1-illicit: 0.4631
# [Run 1] Iter 26 F1-illicit: 0.4682
# [Run 1] Iter 27 F1-illicit: 0.4706
# [Run 1] Iter 28 F1-illicit: 0.4794
# [Run 1] Iter 29 F1-illicit: 0.4653
# [Run 1] Iter 30 F1-illicit: 0.4414
# [Run 1] Iter 31 F1-illicit: 0.4499
# [Run 1] Iter 32 F1-illicit: 0.4696
# [Run 1] Iter 33 F1-illicit: 0.4502
# [Run 1] Iter 34 F1-illicit: 0.4567
# [Run 1] Iter 35 F1-illicit: 0.4565
# [Run 1] Iter 36 F1-illicit: 0.4621
# [Run 1] Iter 37 F1-illicit: 0.4525
# [Run 1] Iter 38 F1-illicit: 0.4610
# [Run 1] Iter 39 F1-illicit: 0.4646
# [Run 1] Iter 40 F1-illicit: 0.4549
# [Run 1] Iter 41 F1-illicit: 0.4535
# [Run 1] Iter 42 F1-illicit: 0.4584
# [Run 5] Iter 26 F1-illicit: 0.6271
# [Run 5] Iter 27 F1-illicit: 0.6254
# [Run 5] Iter 28 F1-illicit: 0.6227
# [Run 5] Iter 29 F1-illicit: 0.6242
# [Run 5] Iter 30 F1-illicit: 0.6380
# [Run 5] Iter 31 F1-illicit: 0.6300
# [Run 5] Iter 32 F1-illicit: 0.6223
# [Run 5] Iter 33 F1-illicit: 0.6279
# [Run 5] Iter 34 F1-illicit: 0.6300
# [Run 5] Iter 35 F1-illicit: 0.6229
# [Run 5] Iter 36 F1-illicit: 0.6207
# [Run 5] Iter 37 F1-illicit: 0.6228
# [Run 5] Iter 38 F1-illicit: 0.6173
# [Run 5] Iter 39 F1-illicit: 0.6176
# [Run 5] Iter 40 F1-illicit: 0.6138
# [Run 5] Iter 41 F1-illicit: 0.6108
# [Run 5] Iter 42 F1-illicit: 0.6059
# [Run 5] Iter 43 F1-illicit: 0.6090
# [Run 5] Iter 44 F1-illicit: 0.6093
# [Run 5] Iter 45 F1-illicit: 0.6128
# [Run 5] Iter 46 F1-illicit: 0.6140
# [Run 5] Iter 47 F1-illicit: 0.6165
# [Run 5] Iter 48 F1-illicit: 0.6125
# [Run 5] Iter 49 F1-illicit: 0.6062
# [Run 5] Iter 50 F1-illicit: 0.6077
# [Run 5] Iter 51 F1-illicit: 0.6045
# [Run 5] Iter 52 F1-illicit: 0.5991
# [Run 5] Iter 53 F1-illicit: 0.5931
# [Run 5] Iter 54 F1-illicit: 0.6030
# [Run 5] Iter 55 F1-illicit: 0.6006
# [Run 5] Iter 56 F1-illicit: 0.5995
# [Run 5] Iter 57 F1-illicit: 0.5966
# [Run 5] Iter 58 F1-illicit: 0.5948
# [Run 5] Iter 59 F1-illicit: 0.5920
# [Run 5] Iter 60 F1-illicit: 0.5900
#
# === Summary ===
# Median F1 per Iteration:
# Iteration 01 (50 samples): Median F1 = 0.2262
# Iteration 02 (100 samples): Median F1 = 0.2061
# Iteration 03 (150 samples): Median F1 = 0.2249
# Iteration 04 (200 samples): Median F1 = 0.2537
# Iteration 05 (250 samples): Median F1 = 0.2669
# Iteration 06 (300 samples): Median F1 = 0.3423
# Iteration 07 (350 samples): Median F1 = 0.3564
# Iteration 08 (400 samples): Median F1 = 0.3777
# Iteration 09 (450 samples): Median F1 = 0.3800
# Iteration 10 (500 samples): Median F1 = 0.4208
# Iteration 11 (550 samples): Median F1 = 0.4427
# Iteration 12 (600 samples): Median F1 = 0.4438
# Iteration 13 (650 samples): Median F1 = 0.4551
# Iteration 14 (700 samples): Median F1 = 0.4723
# Iteration 15 (750 samples): Median F1 = 0.4635
# Iteration 16 (800 samples): Median F1 = 0.5125
# Iteration 17 (850 samples): Median F1 = 0.5002
# Iteration 18 (900 samples): Median F1 = 0.5132
# Iteration 19 (950 samples): Median F1 = 0.5025
# Iteration 20 (1000 samples): Median F1 = 0.5289
# Iteration 21 (1050 samples): Median F1 = 0.5170
# Iteration 22 (1100 samples): Median F1 = 0.5181
# Iteration 23 (1150 samples): Median F1 = 0.5141
# Iteration 24 (1200 samples): Median F1 = 0.5170
# Iteration 25 (1250 samples): Median F1 = 0.5259
# Iteration 26 (1300 samples): Median F1 = 0.5282
# Iteration 27 (1350 samples): Median F1 = 0.5382
# Iteration 28 (1400 samples): Median F1 = 0.5455
# Iteration 29 (1450 samples): Median F1 = 0.5335
# Iteration 30 (1500 samples): Median F1 = 0.5375
# Iteration 31 (1550 samples): Median F1 = 0.5398
# Iteration 32 (1600 samples): Median F1 = 0.5379
# Iteration 33 (1650 samples): Median F1 = 0.5365
# Iteration 34 (1700 samples): Median F1 = 0.5238
# Iteration 35 (1750 samples): Median F1 = 0.5400
# Iteration 36 (1800 samples): Median F1 = 0.5287
# Iteration 37 (1850 samples): Median F1 = 0.5267
# Iteration 38 (1900 samples): Median F1 = 0.5157
# Iteration 39 (1950 samples): Median F1 = 0.5083
# Iteration 40 (2000 samples): Median F1 = 0.5152
# Iteration 41 (2050 samples): Median F1 = 0.5017
# Iteration 42 (2100 samples): Median F1 = 0.4954
# Iteration 43 (2150 samples): Median F1 = 0.5135
# Iteration 44 (2200 samples): Median F1 = 0.4998
# Iteration 45 (2250 samples): Median F1 = 0.4954
# Iteration 46 (2300 samples): Median F1 = 0.4987
# Iteration 47 (2350 samples): Median F1 = 0.5101
# Iteration 48 (2400 samples): Median F1 = 0.5087
# Iteration 49 (2450 samples): Median F1 = 0.5082
# Iteration 50 (2500 samples): Median F1 = 0.5138
# Iteration 51 (2550 samples): Median F1 = 0.5056
# Iteration 52 (2600 samples): Median F1 = 0.5037
# Iteration 53 (2650 samples): Median F1 = 0.5035
# Iteration 54 (2700 samples): Median F1 = 0.5035
# Iteration 55 (2750 samples): Median F1 = 0.4995
# Iteration 56 (2800 samples): Median F1 = 0.5037
# Iteration 57 (2850 samples): Median F1 = 0.5036
# Iteration 58 (2900 samples): Median F1 = 0.5000
# Iteration 59 (2950 samples): Median F1 = 0.4972
# Iteration 60 (3000 samples): Median F1 = 0.4973
#
# Final Median F1 (illicit): 0.4973
# Average Warm-up size: 2050
# Average Active Learning size: 3000
# Average Final Training set size: 5050

# %% [markdown]
# # Active Learning: IF + Expected Model Change + Logistic Regression

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import IsolationForest
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score
import matplotlib.pyplot as plt

# Step 1: Load labeled data
labeled_df = pd.read_csv('elliptic_txs_features_labeled.csv')

# Step 2: Split data
train_df = labeled_df[labeled_df['time_step'] <= 34].reset_index(drop=True)
test_df = labeled_df[labeled_df['time_step'] >= 35].reset_index(drop=True)

X_test = test_df.drop(columns=['txId', 'time_step', 'class'])
y_test = (test_df['class'] == 1).astype(int)

feature_columns = [col for col in train_df.columns if col.startswith('feature_') or col.startswith('f')]

# Step 3: Config
batch_size = 50
max_iterations = 60
N_runs = 5
all_f1_scores = []
warmup_sizes = []
active_sizes = []
final_sizes = []

# Step 4: Active Learning across N runs
for run in range(N_runs):
    print(f"\n=== Run {run+1}/{N_runs} ===")

    unlabeled_pool = train_df.copy()
    labeled_pool = pd.DataFrame(columns=train_df.columns)
    f1_scores = []

    # Warm-up via Isolation Forest
    iso_forest = IsolationForest(random_state=run+1)
    iso_forest.fit(unlabeled_pool[feature_columns])
    scores = -iso_forest.score_samples(unlabeled_pool[feature_columns])
    unlabeled_pool['anomaly_score'] = scores
    unlabeled_pool = unlabeled_pool.sort_values(by='anomaly_score', ascending=False).reset_index(drop=True)

    pointer = 0
    found_illicit = False
    while not found_illicit and pointer < len(unlabeled_pool):
        batch = unlabeled_pool.iloc[pointer:pointer+batch_size]
        labeled_pool = pd.concat([labeled_pool, batch], ignore_index=True)
        pointer += batch_size
        found_illicit = (labeled_pool['class'] == 1).sum() > 0

    warmup_count = len(labeled_pool)
    print(f"Warm-up selected {warmup_count} samples. Found illicit: {(labeled_pool['class'] == 1).sum()}")

    unlabeled_pool = unlabeled_pool.iloc[pointer:].drop(columns='anomaly_score').reset_index(drop=True)

    # Active Learning loop
    iteration = 1
    active_selected = 0
    while len(unlabeled_pool) > 0 and iteration <= max_iterations:
        X_train = labeled_pool[feature_columns]
        y_train = (labeled_pool['class'] == 1).astype(int)

        lr_model = LogisticRegression(max_iter=1000, solver='lbfgs', random_state=run+1)
        lr_model.fit(X_train, y_train)

        y_pred = lr_model.predict(X_test)
        f1 = f1_score(y_test, y_pred, pos_label=1)
        f1_scores.append(f1)
        print(f"[Run {run+1}] Iteration {iteration:02d} - F1 illicit: {f1:.4f}")

        # Expected Model Change strategy
        probs = lr_model.predict_proba(unlabeled_pool[feature_columns])
        grads = probs[:, 1] * (1 - probs[:, 1])
        emc_score = grads

        select_idx = np.argsort(emc_score)[-batch_size:]
        new_batch = unlabeled_pool.iloc[select_idx]

        labeled_pool = pd.concat([labeled_pool, new_batch], ignore_index=True)
        unlabeled_pool = unlabeled_pool.drop(unlabeled_pool.index[select_idx]).reset_index(drop=True)

        active_selected += len(new_batch)
        iteration += 1

    total_final_train = len(labeled_pool)
    all_f1_scores.append(f1_scores)
    warmup_sizes.append(warmup_count)
    active_sizes.append(active_selected)
    final_sizes.append(total_final_train)

    run_median = np.median(f1_scores)
    print(f"[Run {run+1}] Median F1 illicit: {run_median:.4f}")
    print(f"[Run {run+1}] Active Learning selected {active_selected} samples.")
    print(f"[Run {run+1}] Final training set size: {total_final_train} samples.")

# Step 5: Convert to matrix
f1_matrix = np.full((N_runs, max_iterations), np.nan)
for i, scores in enumerate(all_f1_scores):
    f1_matrix[i, :len(scores)] = scores

# Step 6: Print each iteration's **median** across 5 runs
median_f1_by_iteration = np.nanmedian(f1_matrix, axis=0)
print("\n=== Median F1 illicit across 5 runs ===")
for i, median_f1 in enumerate(median_f1_by_iteration):
    print(f"Iteration {i+1:02d} ({(i+1)*batch_size} samples): Median F1 = {median_f1:.4f}")

# Step 7: Final evaluation per paper
final_f1s = f1_matrix[:, -1]
median_final_f1 = np.nanmedian(final_f1s)
std_final_f1 = np.nanstd(final_f1s)
ci_95 = 1.57 * std_final_f1 / np.sqrt(N_runs)

print(f"\n===== Final Evaluation (Paper style) =====")
print(f"Median Final F1 illicit (last iteration): {median_final_f1:.4f}")
print(f"~95% Confidence Interval: ±{ci_95:.4f}")

# Step 8: Print average sizes
print(f"\n===== Average Sample Counts =====")
print(f"Average Warm-up Size: {np.mean(warmup_sizes):.1f}")
print(f"Average Active Learning Size: {np.mean(active_sizes):.1f}")
print(f"Average Final Training Set Size: {np.mean(final_sizes):.1f}")

# Step 9: Plot
median_curve = np.nanmedian(f1_matrix, axis=0)
std_curve = np.nanstd(f1_matrix, axis=0)
ci_95_curve = 1.57 * std_curve / np.sqrt(N_runs)
x_axis = np.arange(1, len(median_curve)+1) * batch_size

plt.figure(figsize=(8, 5))
plt.plot(x_axis, median_curve, marker='o', label='Median F1 (N=5 runs)')
plt.fill_between(x_axis, median_curve - ci_95_curve, median_curve + ci_95_curve, alpha=0.2, label='~95% CI')
plt.title("Active Learning (Expected Model Change + Logistic Regression)")
plt.xlabel("Number of Labeled Samples")
plt.ylabel("Illicit F1-score")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# === Run 1/5 ===
# C:\Users\frank\AppData\Local\Temp\ipykernel_16632\1014623191.py:48: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   labeled_pool = pd.concat([labeled_pool, batch], ignore_index=True)
# Warm-up selected 2150 samples. Found illicit: 1
# [Run 1] Iteration 01 - F1 illicit: 0.0036
# [Run 1] Iteration 02 - F1 illicit: 0.0053
# [Run 1] Iteration 03 - F1 illicit: 0.0000
# [Run 1] Iteration 04 - F1 illicit: 0.0018
# [Run 1] Iteration 05 - F1 illicit: 0.0036
# [Run 1] Iteration 06 - F1 illicit: 0.0152
# [Run 1] Iteration 07 - F1 illicit: 0.0154
# [Run 1] Iteration 08 - F1 illicit: 0.0203
# [Run 1] Iteration 09 - F1 illicit: 0.0304
# [Run 1] Iteration 10 - F1 illicit: 0.0257
# [Run 1] Iteration 11 - F1 illicit: 0.1285
# [Run 1] Iteration 12 - F1 illicit: 0.2685
# [Run 1] Iteration 13 - F1 illicit: 0.2784
# [Run 1] Iteration 14 - F1 illicit: 0.3562
# [Run 1] Iteration 15 - F1 illicit: 0.3851
# [Run 1] Iteration 16 - F1 illicit: 0.3716
# [Run 1] Iteration 17 - F1 illicit: 0.3155
# [Run 1] Iteration 18 - F1 illicit: 0.3048
# [Run 1] Iteration 19 - F1 illicit: 0.3823
# [Run 1] Iteration 20 - F1 illicit: 0.3928
# [Run 1] Iteration 21 - F1 illicit: 0.4814
# [Run 1] Iteration 22 - F1 illicit: 0.5272
# [Run 1] Iteration 23 - F1 illicit: 0.5217
# [Run 1] Iteration 24 - F1 illicit: 0.5205
# [Run 1] Iteration 25 - F1 illicit: 0.5155
# [Run 1] Iteration 26 - F1 illicit: 0.5196
# [Run 1] Iteration 27 - F1 illicit: 0.5265
# [Run 1] Iteration 28 - F1 illicit: 0.5279
# [Run 1] Iteration 29 - F1 illicit: 0.5225
# [Run 1] Iteration 30 - F1 illicit: 0.5317
# [Run 1] Iteration 31 - F1 illicit: 0.5430
# [Run 1] Iteration 32 - F1 illicit: 0.5486
# [Run 1] Iteration 33 - F1 illicit: 0.5488
# [Run 1] Iteration 34 - F1 illicit: 0.5302
# [Run 1] Iteration 35 - F1 illicit: 0.5357
# [Run 5] Iteration 45 - F1 illicit: 0.4828
# [Run 5] Iteration 46 - F1 illicit: 0.4829
# [Run 5] Iteration 47 - F1 illicit: 0.4867
# [Run 5] Iteration 48 - F1 illicit: 0.4798
# [Run 5] Iteration 49 - F1 illicit: 0.4964
# [Run 5] Iteration 50 - F1 illicit: 0.5030
# [Run 5] Iteration 51 - F1 illicit: 0.5121
# [Run 5] Iteration 52 - F1 illicit: 0.4997
# [Run 5] Iteration 53 - F1 illicit: 0.4990
# [Run 5] Iteration 54 - F1 illicit: 0.5012
# [Run 5] Iteration 55 - F1 illicit: 0.5010
# [Run 5] Iteration 56 - F1 illicit: 0.5016
# [Run 5] Iteration 57 - F1 illicit: 0.4979
# [Run 5] Iteration 58 - F1 illicit: 0.4987
# [Run 5] Iteration 59 - F1 illicit: 0.5033
# [Run 5] Iteration 60 - F1 illicit: 0.5052
# [Run 5] Median F1 illicit: 0.4800
# [Run 5] Active Learning selected 3000 samples.
# [Run 5] Final training set size: 5900 samples.
#
# === Median F1 illicit across 5 runs ===
# Iteration 01 (50 samples): Median F1 = 0.0018
# Iteration 02 (100 samples): Median F1 = 0.0053
# Iteration 03 (150 samples): Median F1 = 0.0018
# Iteration 04 (200 samples): Median F1 = 0.0078
# Iteration 05 (250 samples): Median F1 = 0.0094
# Iteration 06 (300 samples): Median F1 = 0.0158
# Iteration 07 (350 samples): Median F1 = 0.0209
# Iteration 08 (400 samples): Median F1 = 0.0592
# Iteration 09 (450 samples): Median F1 = 0.0786
# Iteration 10 (500 samples): Median F1 = 0.0918
# Iteration 11 (550 samples): Median F1 = 0.1301
# Iteration 12 (600 samples): Median F1 = 0.1722
# Iteration 13 (650 samples): Median F1 = 0.2182
# Iteration 14 (700 samples): Median F1 = 0.2634
# Iteration 15 (750 samples): Median F1 = 0.2930
# Iteration 16 (800 samples): Median F1 = 0.3716
# Iteration 17 (850 samples): Median F1 = 0.3565
# Iteration 18 (900 samples): Median F1 = 0.3513
# Iteration 19 (950 samples): Median F1 = 0.3823
# Iteration 20 (1000 samples): Median F1 = 0.3928
# Iteration 21 (1050 samples): Median F1 = 0.4354
# Iteration 22 (1100 samples): Median F1 = 0.4431
# Iteration 23 (1150 samples): Median F1 = 0.5020
# Iteration 24 (1200 samples): Median F1 = 0.5156
# Iteration 25 (1250 samples): Median F1 = 0.5647
# Iteration 26 (1300 samples): Median F1 = 0.5625
# Iteration 27 (1350 samples): Median F1 = 0.5334
# Iteration 28 (1400 samples): Median F1 = 0.5556
# Iteration 29 (1450 samples): Median F1 = 0.5379
# Iteration 30 (1500 samples): Median F1 = 0.5648
# Iteration 31 (1550 samples): Median F1 = 0.5653
# Iteration 32 (1600 samples): Median F1 = 0.5656
# Iteration 33 (1650 samples): Median F1 = 0.5593
# Iteration 34 (1700 samples): Median F1 = 0.5541
# Iteration 35 (1750 samples): Median F1 = 0.5579
# Iteration 36 (1800 samples): Median F1 = 0.5699
# Iteration 37 (1850 samples): Median F1 = 0.5627
# Iteration 38 (1900 samples): Median F1 = 0.5671
# Iteration 39 (1950 samples): Median F1 = 0.5693
# Iteration 40 (2000 samples): Median F1 = 0.5786
# Iteration 41 (2050 samples): Median F1 = 0.5701
# Iteration 42 (2100 samples): Median F1 = 0.5699
# Iteration 43 (2150 samples): Median F1 = 0.5712
# Iteration 44 (2200 samples): Median F1 = 0.5716
# Iteration 45 (2250 samples): Median F1 = 0.5695
# Iteration 46 (2300 samples): Median F1 = 0.5695
# Iteration 47 (2350 samples): Median F1 = 0.5775
# Iteration 48 (2400 samples): Median F1 = 0.5728
# Iteration 49 (2450 samples): Median F1 = 0.5722
# Iteration 50 (2500 samples): Median F1 = 0.5755
# Iteration 51 (2550 samples): Median F1 = 0.5729
# Iteration 52 (2600 samples): Median F1 = 0.5718
# Iteration 53 (2650 samples): Median F1 = 0.5709
# Iteration 54 (2700 samples): Median F1 = 0.5753
# Iteration 55 (2750 samples): Median F1 = 0.5717
# Iteration 56 (2800 samples): Median F1 = 0.5696
# Iteration 57 (2850 samples): Median F1 = 0.5687
# Iteration 58 (2900 samples): Median F1 = 0.5720
# Iteration 59 (2950 samples): Median F1 = 0.5694
# Iteration 60 (3000 samples): Median F1 = 0.5701
#
# ===== Final Evaluation (Paper style) =====
# Median Final F1 illicit (last iteration): 0.5701
# ~95% Confidence Interval: ±0.0278
#
# ===== Average Sample Counts =====
# Average Warm-up Size: 2050.0
# Average Active Learning Size: 3000.0
# Average Final Training Set Size: 5050.0

# %% [markdown]
# # Active Learning: Random Sampling + Uncertainty Sampling + Logistic Regression

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score
import matplotlib.pyplot as plt

# Load data
labeled_df = pd.read_csv("elliptic_txs_features_labeled.csv")

# Split train/test by time_step
train_df = labeled_df[labeled_df['time_step'] <= 34].reset_index(drop=True)
test_df = labeled_df[labeled_df['time_step'] >= 35].reset_index(drop=True)

X_test = test_df.drop(columns=['txId', 'time_step', 'class'])
y_test = (test_df['class'] == 1).astype(int)

feature_columns = [col for col in train_df.columns if col.startswith('feature_') or col.startswith('f')]

# Config
batch_size = 50
max_iterations = 60  # ← updated from 30 to 60
N_runs = 5
all_f1_scores = []
warmup_sizes = []
active_sizes = []

for run in range(N_runs):
    print(f"\n=== Run {run+1}/{N_runs} ===")
    unlabeled_pool = train_df.copy()
    
    # Random warm-up initialization
    labeled_pool = unlabeled_pool.sample(n=batch_size, random_state=run).copy()
    unlabeled_pool = unlabeled_pool.drop(labeled_pool.index).reset_index(drop=True)
    labeled_pool = labeled_pool.reset_index(drop=True)
    warmup_sizes.append(batch_size)
    
    f1_scores = []

    # Active Learning Loop (Uncertainty Sampling)
    iteration = 1
    while len(unlabeled_pool) > 0 and iteration <= max_iterations:
        X_train = labeled_pool[feature_columns]
        y_train = (labeled_pool['class'] == 1).astype(int)

        model = LogisticRegression(max_iter=300, solver='liblinear', random_state=run)
        model.fit(X_train, y_train)

        y_pred = model.predict(X_test)
        f1 = f1_score(y_test, y_pred, pos_label=1)
        f1_scores.append(f1)
        print(f"[Run {run+1}] Iter {iteration:02d} F1-illicit: {f1:.4f}")

        # Uncertainty sampling
        proba = model.predict_proba(unlabeled_pool[feature_columns])[:, 1]
        uncertainty = np.abs(proba - 0.5)
        select_idx = np.argsort(uncertainty)[:batch_size]

        new_batch = unlabeled_pool.iloc[select_idx]
        labeled_pool = pd.concat([labeled_pool, new_batch], ignore_index=True)
        unlabeled_pool = unlabeled_pool.drop(unlabeled_pool.index[select_idx]).reset_index(drop=True)

        iteration += 1

    all_f1_scores.append(f1_scores)
    active_sizes.append(len(f1_scores) * batch_size)

# --- Evaluation ---
max_len = max(len(scores) for scores in all_f1_scores)
f1_matrix = np.full((N_runs, max_len), np.nan)
for i, scores in enumerate(all_f1_scores):
    f1_matrix[i, :len(scores)] = scores

median_f1_per_iter = np.nanmedian(f1_matrix, axis=0)
final_median_f1 = np.nanmedian([scores[-1] for scores in all_f1_scores if len(scores) == max_len])

# --- Output ---
print("\n=== Summary ===")
print("Median F1 per Iteration:")
for i, f1 in enumerate(median_f1_per_iter):
    print(f"Iteration {i+1:02d} ({(i+1)*batch_size} samples): Median F1 = {f1:.4f}")

print(f"\nFinal Median F1 (illicit): {round(final_median_f1, 4)}")
print("Average Warm-up Size:", int(np.mean(warmup_sizes)))
print("Average Active Learning Size:", int(np.mean(active_sizes)))
print("Average Final Training Set Size:", int(np.mean(np.array(warmup_sizes) + np.array(active_sizes))))

# --- Plot ---
plt.figure(figsize=(8, 5))
plt.plot(np.arange(1, len(median_f1_per_iter)+1)*batch_size, median_f1_per_iter, label='Median F1', marker='o')
plt.xlabel("Number of Labeled Samples")
plt.ylabel("Illicit F1-score")
plt.title("Active Learning: Random Init + Uncertainty Sampling + Logistic Regression")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# === Run 1/5 ===
# [Run 1] Iter 01 F1-illicit: 0.2294
# [Run 1] Iter 02 F1-illicit: 0.2165
# [Run 1] Iter 03 F1-illicit: 0.2436
# [Run 1] Iter 04 F1-illicit: 0.2685
# [Run 1] Iter 05 F1-illicit: 0.2837
# [Run 1] Iter 06 F1-illicit: 0.3092
# [Run 1] Iter 07 F1-illicit: 0.2900
# [Run 1] Iter 08 F1-illicit: 0.3059
# [Run 1] Iter 09 F1-illicit: 0.3238
# [Run 1] Iter 10 F1-illicit: 0.3264
# [Run 1] Iter 11 F1-illicit: 0.3849
# [Run 1] Iter 12 F1-illicit: 0.3933
# [Run 1] Iter 13 F1-illicit: 0.4115
# [Run 1] Iter 14 F1-illicit: 0.4115
# [Run 1] Iter 15 F1-illicit: 0.3995
# [Run 1] Iter 16 F1-illicit: 0.4757
# [Run 1] Iter 17 F1-illicit: 0.5149
# [Run 1] Iter 18 F1-illicit: 0.5210
# [Run 1] Iter 19 F1-illicit: 0.5352
# [Run 1] Iter 20 F1-illicit: 0.5109
# [Run 1] Iter 21 F1-illicit: 0.5072
# [Run 1] Iter 22 F1-illicit: 0.5154
# [Run 1] Iter 23 F1-illicit: 0.5218
# [Run 1] Iter 24 F1-illicit: 0.5212
# [Run 1] Iter 25 F1-illicit: 0.5163
# [Run 1] Iter 26 F1-illicit: 0.5013
# [Run 5] Iter 21 F1-illicit: 0.4791
# [Run 5] Iter 22 F1-illicit: 0.5218
# [Run 5] Iter 23 F1-illicit: 0.5072
# [Run 5] Iter 24 F1-illicit: 0.4835
# [Run 5] Iter 25 F1-illicit: 0.4934
# [Run 5] Iter 26 F1-illicit: 0.4967
# [Run 5] Iter 27 F1-illicit: 0.4942
# [Run 5] Iter 28 F1-illicit: 0.4872
# [Run 5] Iter 29 F1-illicit: 0.4990
# [Run 5] Iter 30 F1-illicit: 0.5051
# [Run 5] Iter 31 F1-illicit: 0.4859
# [Run 5] Iter 32 F1-illicit: 0.4963
# [Run 5] Iter 33 F1-illicit: 0.4789
# [Run 5] Iter 34 F1-illicit: 0.4953
# [Run 5] Iter 35 F1-illicit: 0.4747
# [Run 5] Iter 36 F1-illicit: 0.4844
# [Run 5] Iter 37 F1-illicit: 0.4739
# [Run 5] Iter 38 F1-illicit: 0.4712
# [Run 5] Iter 39 F1-illicit: 0.4729
# [Run 5] Iter 40 F1-illicit: 0.4677
# [Run 5] Iter 41 F1-illicit: 0.4670
# [Run 5] Iter 42 F1-illicit: 0.4684
# [Run 5] Iter 43 F1-illicit: 0.4589
# [Run 5] Iter 44 F1-illicit: 0.4585
# [Run 5] Iter 45 F1-illicit: 0.4640
# [Run 5] Iter 46 F1-illicit: 0.4650
# [Run 5] Iter 47 F1-illicit: 0.4649
# [Run 5] Iter 48 F1-illicit: 0.4628
# [Run 5] Iter 49 F1-illicit: 0.4549
# [Run 5] Iter 50 F1-illicit: 0.4611
# [Run 5] Iter 51 F1-illicit: 0.4574
# [Run 5] Iter 52 F1-illicit: 0.4558
# [Run 5] Iter 53 F1-illicit: 0.4562
# [Run 5] Iter 54 F1-illicit: 0.4528
# [Run 5] Iter 55 F1-illicit: 0.4556
# [Run 5] Iter 56 F1-illicit: 0.4556
# [Run 5] Iter 57 F1-illicit: 0.4653
# [Run 5] Iter 58 F1-illicit: 0.4684
# [Run 5] Iter 59 F1-illicit: 0.4684
# [Run 5] Iter 60 F1-illicit: 0.4611
#
# === Summary ===
# Median F1 per Iteration:
# Iteration 01 (50 samples): Median F1 = 0.1747
# Iteration 02 (100 samples): Median F1 = 0.2246
# Iteration 03 (150 samples): Median F1 = 0.2436
# Iteration 04 (200 samples): Median F1 = 0.2685
# Iteration 05 (250 samples): Median F1 = 0.3151
# Iteration 06 (300 samples): Median F1 = 0.3781
# Iteration 07 (350 samples): Median F1 = 0.3972
# Iteration 08 (400 samples): Median F1 = 0.4153
# Iteration 09 (450 samples): Median F1 = 0.4352
# Iteration 10 (500 samples): Median F1 = 0.4433
# Iteration 11 (550 samples): Median F1 = 0.4418
# Iteration 12 (600 samples): Median F1 = 0.4549
# Iteration 13 (650 samples): Median F1 = 0.4522
# Iteration 14 (700 samples): Median F1 = 0.4482
# Iteration 15 (750 samples): Median F1 = 0.4492
# Iteration 16 (800 samples): Median F1 = 0.4757
# Iteration 17 (850 samples): Median F1 = 0.5149
# Iteration 18 (900 samples): Median F1 = 0.5210
# Iteration 19 (950 samples): Median F1 = 0.5162
# Iteration 20 (1000 samples): Median F1 = 0.5109
# Iteration 21 (1050 samples): Median F1 = 0.4791
# Iteration 22 (1100 samples): Median F1 = 0.5154
# Iteration 23 (1150 samples): Median F1 = 0.5218
# Iteration 24 (1200 samples): Median F1 = 0.5212
# Iteration 25 (1250 samples): Median F1 = 0.5163
# Iteration 26 (1300 samples): Median F1 = 0.5013
# Iteration 27 (1350 samples): Median F1 = 0.5117
# Iteration 28 (1400 samples): Median F1 = 0.5172
# Iteration 29 (1450 samples): Median F1 = 0.5139
# Iteration 30 (1500 samples): Median F1 = 0.5197
# Iteration 31 (1550 samples): Median F1 = 0.5082
# Iteration 32 (1600 samples): Median F1 = 0.5161
# Iteration 33 (1650 samples): Median F1 = 0.5139
# Iteration 34 (1700 samples): Median F1 = 0.5276
# Iteration 35 (1750 samples): Median F1 = 0.5271
# Iteration 36 (1800 samples): Median F1 = 0.5261
# Iteration 37 (1850 samples): Median F1 = 0.5333
# Iteration 38 (1900 samples): Median F1 = 0.5364
# Iteration 39 (1950 samples): Median F1 = 0.5343
# Iteration 40 (2000 samples): Median F1 = 0.5391
# Iteration 41 (2050 samples): Median F1 = 0.5318
# Iteration 42 (2100 samples): Median F1 = 0.5410
# Iteration 43 (2150 samples): Median F1 = 0.5428
# Iteration 44 (2200 samples): Median F1 = 0.5254
# Iteration 45 (2250 samples): Median F1 = 0.5363
# Iteration 46 (2300 samples): Median F1 = 0.5259
# Iteration 47 (2350 samples): Median F1 = 0.5307
# Iteration 48 (2400 samples): Median F1 = 0.5245
# Iteration 49 (2450 samples): Median F1 = 0.5253
# Iteration 50 (2500 samples): Median F1 = 0.5342
# Iteration 51 (2550 samples): Median F1 = 0.5229
# Iteration 52 (2600 samples): Median F1 = 0.5201
# Iteration 53 (2650 samples): Median F1 = 0.5249
# Iteration 54 (2700 samples): Median F1 = 0.5210
# Iteration 55 (2750 samples): Median F1 = 0.5160
# Iteration 56 (2800 samples): Median F1 = 0.5143
# Iteration 57 (2850 samples): Median F1 = 0.5145
# Iteration 58 (2900 samples): Median F1 = 0.5140
# Iteration 59 (2950 samples): Median F1 = 0.5150
# Iteration 60 (3000 samples): Median F1 = 0.5115
#
# Final Median F1 (illicit): 0.5115
# Average Warm-up Size: 50
# Average Active Learning Size: 3000
# Average Final Training Set Size: 3050

# %% [markdown]
# # Active Learning: Random Sampling + Expected Model Change + Logistic Regression

# %%
# Active Learning: Random Sampling + Expected Model Change + Logistic Regression

import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score
import matplotlib.pyplot as plt

# Load data
labeled_df = pd.read_csv('elliptic_txs_features_labeled.csv')
train_df = labeled_df[labeled_df['time_step'] <= 34].reset_index(drop=True)
test_df = labeled_df[labeled_df['time_step'] >= 35].reset_index(drop=True)

X_test = test_df.drop(columns=['txId', 'time_step', 'class'])
y_test = (test_df['class'] == 1).astype(int)

feature_columns = [col for col in train_df.columns if col.startswith('feature_') or col.startswith('f')]

# Config
batch_size = 50
max_iterations = 60  # <-- Updated to 60 iterations
N_runs = 5
all_f1_scores = []
warmup_sizes = []
active_sizes = []

# Active Learning with Random Init + EMC Loop
for run in range(N_runs):
    print(f"\n=== Run {run+1}/{N_runs} ===")
    np.random.seed(run+1)

    unlabeled_pool = train_df.copy()
    labeled_pool = unlabeled_pool.sample(n=batch_size, random_state=run+1)
    unlabeled_pool = unlabeled_pool.drop(labeled_pool.index).reset_index(drop=True)
    labeled_pool = labeled_pool.reset_index(drop=True)

    f1_scores = []
    active_selected = 0

    for iteration in range(1, max_iterations + 1):
        X_train = labeled_pool[feature_columns]
        y_train = (labeled_pool['class'] == 1).astype(int)

        lr_model = LogisticRegression(max_iter=1000, solver='lbfgs', random_state=run+1)
        lr_model.fit(X_train, y_train)

        y_pred = lr_model.predict(X_test)
        f1 = f1_score(y_test, y_pred, pos_label=1)
        f1_scores.append(f1)
        print(f"[Run {run+1}] Iteration {iteration:02d} - F1 illicit: {f1:.4f}")

        probs = lr_model.predict_proba(unlabeled_pool[feature_columns])
        grads = probs[:, 1] * (1 - probs[:, 1])
        emc_score = grads

        select_idx = np.argsort(emc_score)[-batch_size:]
        new_batch = unlabeled_pool.iloc[select_idx]

        labeled_pool = pd.concat([labeled_pool, new_batch], ignore_index=True)
        unlabeled_pool = unlabeled_pool.drop(unlabeled_pool.index[select_idx]).reset_index(drop=True)
        active_selected += len(new_batch)

        if len(unlabeled_pool) == 0:
            break

    total_final_train = len(labeled_pool)
    all_f1_scores.append(f1_scores)
    warmup_sizes.append(batch_size)
    active_sizes.append(active_selected)

    run_median = np.median(f1_scores)
    print(f"[Run {run+1}] Median F1 illicit: {run_median:.4f}")
    print(f"[Run {run+1}] Active Learning selected {active_selected} samples.")
    print(f"[Run {run+1}] Final training set size: {total_final_train} samples.")

# Results Summary
f1_matrix = np.full((N_runs, max_iterations), np.nan)
for i, scores in enumerate(all_f1_scores):
    f1_matrix[i, :len(scores)] = scores

median_f1_by_iteration = np.nanmedian(f1_matrix, axis=0)

print("\n=== Median F1 illicit across 5 runs ===")
for i, median_f1 in enumerate(median_f1_by_iteration):
    print(f"Iteration {i+1:02d} ({(i+1)*batch_size} samples): Median F1 = {median_f1:.4f}")

# Final evaluation (paper-style)
final_f1s = [scores[-1] for scores in all_f1_scores if len(scores) == max_iterations]
median_final_f1 = np.nanmedian(final_f1s)
std_final_f1 = np.nanstd(final_f1s)
ci_95 = 1.57 * std_final_f1 / np.sqrt(N_runs)

print(f"\n===== Final Evaluation (Paper style) =====")
print(f"Median Final F1 illicit (last iteration): {median_final_f1:.4f}")
print(f"~95% Confidence Interval: ±{ci_95:.4f}")

# Print average sizes
print(f"\n===== Average Sample Counts =====")
print(f"Average Warm-up Size: {np.mean(warmup_sizes):.1f}")
print(f"Average Active Learning Size: {np.mean(active_sizes):.1f}")
print(f"Average Final Training Set Size: {np.mean(np.array(warmup_sizes) + np.array(active_sizes)):.1f}")

# Plot
std_curve = np.nanstd(f1_matrix, axis=0)
ci_95_curve = 1.57 * std_curve / np.sqrt(N_runs)
x_axis = np.arange(1, len(median_f1_by_iteration)+1) * batch_size

# Iteration 09 (450 samples): Median F1 = 0.5217
# Iteration 10 (500 samples): Median F1 = 0.5533
# Iteration 11 (550 samples): Median F1 = 0.5662
# Iteration 12 (600 samples): Median F1 = 0.5786
# Iteration 13 (650 samples): Median F1 = 0.5861
# Iteration 14 (700 samples): Median F1 = 0.5749
# Iteration 15 (750 samples): Median F1 = 0.5679
# Iteration 16 (800 samples): Median F1 = 0.5610
# Iteration 17 (850 samples): Median F1 = 0.5636
# Iteration 18 (900 samples): Median F1 = 0.5429
# Iteration 19 (950 samples): Median F1 = 0.5414
# Iteration 20 (1000 samples): Median F1 = 0.5443
# Iteration 21 (1050 samples): Median F1 = 0.5514
# Iteration 22 (1100 samples): Median F1 = 0.5464
# Iteration 23 (1150 samples): Median F1 = 0.5416
# Iteration 24 (1200 samples): Median F1 = 0.5562
# Iteration 25 (1250 samples): Median F1 = 0.5292
# Iteration 26 (1300 samples): Median F1 = 0.5265
# Iteration 27 (1350 samples): Median F1 = 0.5194
# Iteration 28 (1400 samples): Median F1 = 0.5220
# Iteration 29 (1450 samples): Median F1 = 0.5408
# Iteration 30 (1500 samples): Median F1 = 0.5401
# Iteration 31 (1550 samples): Median F1 = 0.5304
# Iteration 32 (1600 samples): Median F1 = 0.5502
# Iteration 33 (1650 samples): Median F1 = 0.5377
# Iteration 34 (1700 samples): Median F1 = 0.5406
# Iteration 35 (1750 samples): Median F1 = 0.5540
# Iteration 36 (1800 samples): Median F1 = 0.5533
# Iteration 37 (1850 samples): Median F1 = 0.5457
# Iteration 38 (1900 samples): Median F1 = 0.5581
# Iteration 39 (1950 samples): Median F1 = 0.5470
# Iteration 40 (2000 samples): Median F1 = 0.5517
# Iteration 41 (2050 samples): Median F1 = 0.5456
# Iteration 42 (2100 samples): Median F1 = 0.5435
# Iteration 43 (2150 samples): Median F1 = 0.5435
# Iteration 44 (2200 samples): Median F1 = 0.5396
# Iteration 45 (2250 samples): Median F1 = 0.5393
# Iteration 46 (2300 samples): Median F1 = 0.5300
# Iteration 47 (2350 samples): Median F1 = 0.5332
# Iteration 48 (2400 samples): Median F1 = 0.5388
# Iteration 49 (2450 samples): Median F1 = 0.5349
# Iteration 50 (2500 samples): Median F1 = 0.5370
# Iteration 51 (2550 samples): Median F1 = 0.5327
# Iteration 52 (2600 samples): Median F1 = 0.5346
# Iteration 53 (2650 samples): Median F1 = 0.5337
# Iteration 54 (2700 samples): Median F1 = 0.5345
# Iteration 55 (2750 samples): Median F1 = 0.5374
# Iteration 56 (2800 samples): Median F1 = 0.5310
# Iteration 57 (2850 samples): Median F1 = 0.5329
# Iteration 58 (2900 samples): Median F1 = 0.5314
# Iteration 59 (2950 samples): Median F1 = 0.5330
# Iteration 60 (3000 samples): Median F1 = 0.5314
#
# ===== Final Evaluation (Paper style) =====
# Median Final F1 illicit (last iteration): 0.5314
# ~95% Confidence Interval: ±0.0390
#
# ===== Average Sample Counts =====
# Average Warm-up Size: 50.0
# Average Active Learning Size: 3000.0
# Average Final Training Set Size: 3050.0
